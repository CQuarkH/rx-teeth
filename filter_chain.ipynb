# %%
import os
import shutil
import pydicom
from PIL import Image

def get_aspect_ratio(file_path):
    """Determina la relación de aspecto de un archivo según su formato"""
    ext = file_path.lower().split('.')[-1]
    
    try:
        if ext == 'dcm':
            dcm = pydicom.dcmread(file_path, stop_before_pixels=True)
            rows = getattr(dcm, "Rows", None)
            cols = getattr(dcm, "Columns", None)
            if rows is None or cols is None:
                return 0
            return cols / rows
        elif ext in ('jpg', 'jpeg', 'png'):
            with Image.open(file_path) as img:
                width, height = img.size
                return width / height
        else:
            return 0
    except Exception as e:
        print(f"Error al procesar {file_path}: {e}")
        return 0

def is_panoramic_by_aspect(file_path, min_ratio=1.5):
    """Considera panorámica toda imagen cuya anchura/altura >= min_ratio."""
    ratio = get_aspect_ratio(file_path)
    return ratio >= min_ratio

# Directorio de salida
no_brackets_output_dir = r"C:\Users\Admn\Documents\rx\data\filtered\panoramic"

if not os.path.exists(no_brackets_output_dir):
    os.makedirs(no_brackets_output_dir)

# Diccionario para llevar la cuenta de nombres repetidos
name_counter = {}

# Lista para almacenar todos los archivos panorámicos encontrados
panoramic_files = []

# Encontrar todas las panorámicas
for root, _, files in os.walk(r"C:\Users\Admn\Documents\rx\data\raw"):
    for fn in files:
        ext = fn.lower().split('.')[-1]
        if ext not in ('dcm', 'jpg', 'jpeg', 'png'):
            continue
        full = os.path.join(root, fn)
        
        if is_panoramic_by_aspect(full, min_ratio=1.5):
            panoramic_files.append((full, fn))

print(f"Encontradas {len(panoramic_files)} panorámicas basadas en aspecto.")

# Copiar todas las panorámicas, renombrando en caso de duplicados
copied_count = 0
renamed_count = 0

for file_path, original_name in panoramic_files:
    base_name, ext = os.path.splitext(original_name)
    
    if original_name in name_counter:
        name_counter[original_name] += 1
        new_name = f"{base_name}_{name_counter[original_name]}{ext}"
        renamed_count += 1
    else:
        name_counter[original_name] = 0
        new_name = original_name
    
    dest_file = os.path.join(no_brackets_output_dir, new_name)
    try:
        shutil.copy2(file_path, dest_file)
        copied_count += 1
        
        # Mostrar progreso
        if copied_count % 100 == 0:
            print(f"Progreso: {copied_count}/{len(panoramic_files)} archivos copiados")
    except Exception as e:
        print(f"Error al copiar {file_path} a {dest_file}: {e}")

# Verificar el resultado final
final_files = os.listdir(no_brackets_output_dir)

print("\n===== RESUMEN =====")
print(f"Total panorámicas identificadas: {len(panoramic_files)}")
print(f"Archivos copiados exitosamente: {copied_count}")
print(f"Archivos renombrados por duplicados: {renamed_count}")
print(f"Total archivos en carpeta destino: {len(final_files)}")
print(f"Archivos guardados en: {no_brackets_output_dir}")
# Out:
# Encontradas 3309 panorámicas basadas en aspecto.
# Progreso: 100/3309 archivos copiados
# Progreso: 200/3309 archivos copiados
# Progreso: 300/3309 archivos copiados
# Progreso: 400/3309 archivos copiados
# Progreso: 500/3309 archivos copiados
# Progreso: 600/3309 archivos copiados
# Progreso: 700/3309 archivos copiados
# Progreso: 800/3309 archivos copiados
# Progreso: 900/3309 archivos copiados
# Progreso: 1000/3309 archivos copiados
# Progreso: 1100/3309 archivos copiados
# Progreso: 1200/3309 archivos copiados
# Progreso: 1300/3309 archivos copiados
# Progreso: 1400/3309 archivos copiados
# Progreso: 1500/3309 archivos copiados
# Progreso: 1600/3309 archivos copiados
# Progreso: 1700/3309 archivos copiados
# Progreso: 1800/3309 archivos copiados
# Progreso: 1900/3309 archivos copiados
# Progreso: 2000/3309 archivos copiados
# Progreso: 2100/3309 archivos copiados
# Progreso: 2200/3309 archivos copiados
# Progreso: 2300/3309 archivos copiados
# Progreso: 2400/3309 archivos copiados
# Progreso: 2500/3309 archivos copiados
# Progreso: 2600/3309 archivos copiados
# Progreso: 2700/3309 archivos copiados
# Progreso: 2800/3309 archivos copiados
# Progreso: 2900/3309 archivos copiados
# Progreso: 3000/3309 archivos copiados
# Progreso: 3100/3309 archivos copiados
# Progreso: 3200/3309 archivos copiados
# Progreso: 3300/3309 archivos copiados
#
# ===== RESUMEN =====
# Total panorámicas identificadas: 3309
# Archivos copiados exitosamente: 3309
# Archivos renombrados por duplicados: 925
# Total archivos en carpeta destino: 3308
# Archivos guardados en: C:\Users\Admn\Documents\rx\data\filtered\panoramic

# %%
import os
import torch
import pydicom
import numpy as np
from PIL import Image
from torchvision import transforms
from torch import nn
from torchvision.models import resnet18
from torch.utils.data import Dataset, DataLoader
import random


class SiameseNet(nn.Module):
    def __init__(self, embedding_dim=128):
        super().__init__()
        self.backbone = resnet18(pretrained=True)
        self.backbone.fc = nn.Linear(self.backbone.fc.in_features, embedding_dim)
    
    def forward_once(self, x):
        return self.backbone(x)
    
    def forward(self, x1, x2):
        # Para entrenamiento, procesamos pares de imágenes
        emb1 = self.forward_once(x1)
        emb2 = self.forward_once(x2)
        return emb1, emb2
    
    def embedding(self, x):
        return self.forward_once(x)

# --- Función para cargar imagen ---
def load_image(path):
    ext = os.path.splitext(path)[1].lower()
    if ext == '.dcm':
        dcm = pydicom.dcmread(path)
        arr = dcm.pixel_array.astype(np.float32)
        # Normalizamos a 0-255
        arr = (arr - arr.min()) * (255.0 / (arr.max() - arr.min()))
        arr = np.clip(arr, 0, 255).astype(np.uint8)
        img = Image.fromarray(arr)
    else:
        # Carga con PIL para JPG, PNG, etc.
        img = Image.open(path).convert('L')
    return img

transform = transforms.Compose([
    transforms.RandomRotation(10),
    transforms.RandomResizedCrop(224, scale=(0.8,1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2,contrast=0.2),
    transforms.Resize((224, 224)),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# --- Dataset para entrenamiento de red siamesa ---
class SiameseDataset(Dataset):
    def __init__(self, leche_dir, def_dir, transform=None):
        self.leche_files = [os.path.join(leche_dir, f) for f in os.listdir(leche_dir)
                          if f.lower().endswith(('.jpg', '.jpeg', '.png', '.dcm'))]
        self.def_files = [os.path.join(def_dir, f) for f in os.listdir(def_dir)
                        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.dcm'))]
        self.transform = transform
        
    def __len__(self):
        # Generamos pares: mismo tipo (positivos) y diferente tipo (negativos)
        return len(self.leche_files) + len(self.def_files)
    
    def __getitem__(self, idx):
        # 50% probabilidad de obtener un par positivo, 50% negativo
        is_same = random.random() > 0.5
        
        if idx < len(self.leche_files):
            img1_path = self.leche_files[idx]
            if is_same:
                # Par positivo: ambos son dientes de leche
                img2_path = random.choice(self.leche_files)
                label = 1  # mismo tipo = 1
            else:
                # Par negativo: uno leche, otro definitivo
                img2_path = random.choice(self.def_files)
                label = 0  # diferente tipo = 0
        else:
            img1_path = self.def_files[idx - len(self.leche_files)]
            if is_same:
                # Par positivo: ambos son dientes definitivos
                img2_path = random.choice(self.def_files)
                label = 1  # mismo tipo = 1
            else:
                # Par negativo: uno definitivo, otro leche
                img2_path = random.choice(self.leche_files)
                label = 0  # diferente tipo = 0
        
        img1 = load_image(img1_path)
        img2 = load_image(img2_path)
        
        if self.transform:
            img1 = self.transform(img1)
            img2 = self.transform(img2)
        
        return img1, img2, torch.FloatTensor([label])

# --- Función de pérdida contrastiva ---
class ContrastiveLoss(nn.Module):
    def __init__(self, margin=1.6): # 2.0
        super(ContrastiveLoss, self).__init__()
        self.margin = margin
    
    def forward(self, output1, output2, label):
        # Calculamos la distancia euclidiana entre las salidas
        euclidean_distance = torch.nn.functional.pairwise_distance(output1, output2)
        # Pérdida contrastiva
        loss = torch.mean(label * euclidean_distance.pow(2) + (1 - label) * torch.clamp(self.margin - euclidean_distance, min=0).pow(2))
        return loss

# --- Directorios con ejemplos etiquetados ---
leche_dir = r"C:\Users\Admn\Documents\rx\data\training\milk-teeth"  # Ruta a carpeta con ejemplos de dientes de leche
def_dir = r"C:\Users\Admn\Documents\rx\data\training\permanent-teeth"  # Ruta a carpeta con ejemplos de dientes definitivos

# --- Configuración del entrenamiento ---
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Usando dispositivo: {device}")
model = SiameseNet(embedding_dim=128).to(device)
criterion = ContrastiveLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)
num_epochs = 20
batch_size = 8

# --- Preparar dataset y dataloader ---
dataset = SiameseDataset(leche_dir, def_dir, transform=transform)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# --- Entrenamiento ---
print("Comenzando entrenamiento...")
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, (img1, img2, label) in enumerate(dataloader):
        img1, img2, label = img1.to(device), img2.to(device), label.to(device)
        
        # Zero gradients
        optimizer.zero_grad()
        
        # Forward pass
        output1, output2 = model(img1, img2)
        
        # Calcular pérdida
        loss = criterion(output1, output2, label)
        
        # Backward y optimización
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
    # Mostrar estadísticas
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(dataloader):.4f}")

# --- Guardar el modelo entrenado ---
torch.save(model.state_dict(), 'siamese_weights.pth')
print("Entrenamiento completado y modelo guardado como 'siamese_weights.pth'")
# Out:
# Usando dispositivo: cuda
# c:\Users\Admn\Desktop\esp3\tf\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Admn\Desktop\esp3\tf\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Comenzando entrenamiento...
# Epoch 1/20, Loss: 4.7386
# Epoch 2/20, Loss: 0.8309
# Epoch 3/20, Loss: 0.7147
# Epoch 4/20, Loss: 0.7175
# Epoch 5/20, Loss: 0.6814
# Epoch 6/20, Loss: 0.6706
# Epoch 7/20, Loss: 0.6791
# Epoch 8/20, Loss: 0.6743
# Epoch 9/20, Loss: 0.6759
# Epoch 10/20, Loss: 0.6616
# Epoch 11/20, Loss: 0.6801
# Epoch 12/20, Loss: 0.6706
# Epoch 13/20, Loss: 0.6687
# Epoch 14/20, Loss: 0.6587
# Epoch 15/20, Loss: 0.7462
# Epoch 16/20, Loss: 0.6867
# Epoch 17/20, Loss: 0.7438
# Epoch 18/20, Loss: 0.7032
# Epoch 19/20, Loss: 0.7198
# Epoch 20/20, Loss: 0.6884
# Entrenamiento completado y modelo guardado como 'siamese_weights.pth'

# %%
import os
import torch
import pydicom
import numpy as np
import shutil
from PIL import Image
from torchvision import transforms
from torch import nn
from torchvision.models import resnet18

# --- Definición de la red siamés ---
class SiameseNet(nn.Module):
    def __init__(self, embedding_dim=128):
        super().__init__()
        self.backbone = resnet18(pretrained=True)
        self.backbone.fc = nn.Linear(self.backbone.fc.in_features, embedding_dim)

    def forward_once(self, x):
        return self.backbone(x)

    def embedding(self, x):
        return self.forward_once(x)

# --- Función para cargar imagen (DICOM o JPG/PNG) como PIL Image ---
def load_image(path):
    ext = os.path.splitext(path)[1].lower()
    if ext == '.dcm':
        dcm = pydicom.dcmread(path)
        arr = dcm.pixel_array.astype(np.float32)
        # Normalizamos a 0-255
        arr = (arr - arr.min()) * (255.0 / (arr.max() - arr.min()))
        arr = np.clip(arr, 0, 255).astype(np.uint8)
        img = Image.fromarray(arr)
    else:
        # Carga con PIL para JPG, PNG, etc.
        img = Image.open(path).convert('L')
    return img

# --- Transformaciones ---
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

def get_class_embedding(directory):
    embeddings = []
    for file in os.listdir(directory):
        if file.lower().endswith(('.jpg', '.jpeg', '.png', '.dcm')):
            path = os.path.join(directory, file)
            try:
                img = transform(load_image(path)).unsqueeze(0).to(device)
                with torch.no_grad():
                    emb = model.embedding(img)
                    embeddings.append(emb)
            except Exception as e:
                print(f"Error procesando {file}: {e}")
    
    if not embeddings:
        raise ValueError(f"No se pudieron cargar imágenes de {directory}")
    
    return torch.mean(torch.cat(embeddings, dim=0), dim=0, keepdim=True)

# --- Carga del modelo y pesos entrenados ---
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SiameseNet(embedding_dim=128).to(device)
state = torch.load('siamese_weights.pth', map_location=device)
model.load_state_dict(state)
model.eval()

leche_dir = r"C:\Users\Admn\Documents\rx\data\training\milk-teeth"  # Ruta a carpeta con ejemplos de dientes de leche
def_dir = r"C:\Users\Admn\Documents\rx\data\training\permanent-teeth"  # Ruta a carpeta con ejemplos de dientes definitivos

with torch.no_grad():
    proto_leche_emb = get_class_embedding(leche_dir)
    proto_def_emb = get_class_embedding(def_dir)

# --- Función de clasificación general ---
def classify_teeth_type(query_path, threshold=None):
    img = transform(load_image(query_path)).unsqueeze(0).to(device)
    with torch.no_grad():
        q_emb = model.embedding(img)
        d_leche = torch.norm(q_emb - proto_leche_emb, p=2).item()
        d_def = torch.norm(q_emb - proto_def_emb, p=2).item()
    label = 'leche' if d_leche < d_def else 'definitivos'
    return (label, min(d_leche, d_def)) if threshold else label

# --- Definir carpetas de destino ---
milk_teeth_dir = r"C:\Users\Admn\Documents\rx\data\filtered\milk-teeth"
permanent_teeth_dir = r"C:\Users\Admn\Documents\rx\data\filtered\permanent-teeth"

# Crear las carpetas si no existen
if not os.path.exists(milk_teeth_dir):
    os.makedirs(milk_teeth_dir)
if not os.path.exists(permanent_teeth_dir):
    os.makedirs(permanent_teeth_dir)

# --- Iteración sobre carpeta con imágenes mixtas ---
raw_dir = r"C:\Users\Admn\Documents\rx\data\filtered\panoramic"
milk_teeth_files = []
permanent_teeth_files = []

for root, _, files in os.walk(raw_dir):
    print(f"Procesando carpeta: {root}")
    print(f"Total de archivos: {len(files)}")
    for fn in files:
        ext = fn.lower().split('.')[-1]
        if ext not in ('dcm', 'jpg', 'jpeg', 'png'):
            continue
        full = os.path.join(root, fn)
        
        # Clasificar la imagen
        label = classify_teeth_type(full)
        
        # Guardar en la carpeta correspondiente
        if label == 'leche':
            milk_teeth_files.append(full)
            dest_file = os.path.join(milk_teeth_dir, fn)
            shutil.copy2(full, dest_file)
            print(f"Copiado a milk-teeth: {fn}")
        else:  # 'definitivos'
            permanent_teeth_files.append(full)
            dest_file = os.path.join(permanent_teeth_dir, fn)
            shutil.copy2(full, dest_file)
            print(f"Copiado a permanent-teeth: {fn}")

print(f"Total panorámicas con dientes de leche: {len(milk_teeth_files)}")
print(f"Total panorámicas con dientes permanentes: {len(permanent_teeth_files)}")
print(f"Archivos de dientes de leche guardados en: {milk_teeth_dir}")
print(f"Archivos de dientes permanentes guardados en: {permanent_teeth_dir}")
# Out:
# Procesando carpeta: C:\Users\Admn\Documents\rx\data\filtered\panoramic
# Total de archivos: 3308
# Copiado a permanent-teeth: ABARZUA MONTECINOS MAURICIO 18-02-02.jpg
# Copiado a milk-teeth: ABARZUA VIDAL MARTIN (2).jpg
# Copiado a permanent-teeth: ABARZUA VIDAL MARTIN.jpg
# Copiado a permanent-teeth: ABARZUA VIDAL MARTIN_1.jpg
# Copiado a permanent-teeth: ABARZUA VIDAL MARTIN_2.jpg
# Copiado a permanent-teeth: ABARZUA VIDAL MARTIN_3.jpg
# Copiado a permanent-teeth: ABELLO BASUALTO ANAHI  (1).jpg
# Copiado a permanent-teeth: ABELLO BASUALTO ANAHI  (1)_1.jpg
# Copiado a permanent-teeth: ABELLO GUZMAN LISSETTE 19-12-99.jpg
# Copiado a permanent-teeth: ABURTO ABURTO MAXIMILIANO (2).jpg
# Copiado a permanent-teeth: ABURTO ABURTO MAXIMILIANO 08-03-06 (2).jpg
# Copiado a permanent-teeth: ABURTO ABURTO MAXIMILIANO.jpg
# Copiado a permanent-teeth: ABURTO CIFUENTES FRANCINY 25-01-01.jpg
# Copiado a permanent-teeth: ABURTO CIFUENTES FRANCINY.jpg
# Copiado a permanent-teeth: ABURTO GALLEGOS CAROLINA.jpg
# Copiado a milk-teeth: ACUÑA BARRA FRANCISCA  (2).jpg
# Copiado a milk-teeth: ACUÑA BARRA FRANCISCA  (2)_1.jpg
# Copiado a permanent-teeth: ACUÑA BASUALTO VALENTINA.jpg
# Copiado a permanent-teeth: ACUÑA ESPINOZA FERNANDA 04-05-06 (2).jpg
# Copiado a permanent-teeth: ACUÑA ESPINOZA FERNANDA.jpg
# Copiado a permanent-teeth: ACUÑA ESPINOZA FERNANDA_1.jpg
# Copiado a permanent-teeth: ACUÑA FULLER BENJAMIN 2021.jpg
# Copiado a permanent-teeth: ACUÑA MANRIQUEZ FERNANDA 25-05-06 (1).jpg
# Copiado a permanent-teeth: ACUÑA MANRIQUEZ FERNANDA.jpg
# Copiado a permanent-teeth: ACUÑA MANRIQUEZ FERNANDA_1.jpg
# Copiado a permanent-teeth: ACUÑA MANRIQUEZ FERNANDA_2.jpg
# Copiado a permanent-teeth: ACUÑA MARTINEZ ANTONELLA.jpg
# Copiado a permanent-teeth: ACUÑA MARTINEZ ANTONELLA_1.jpg
# Copiado a permanent-teeth: ACUÑA MARTINEZ ANTONELLA_2.jpg
# Copiado a permanent-teeth: ACUÑA OSORIO ALVARO.jpg
# Copiado a permanent-teeth: ACUÑA OSORIO SEBASTIAN.jpg
# Copiado a permanent-teeth: ACUÑA SANTANA NOELIA.jpg
# Copiado a milk-teeth: AEDO CURIHUAL JEDAI 08-04-03.jpg
# Copiado a permanent-teeth: AEDO JARA ARELY 17-04-04 (2).jpg
# Copiado a permanent-teeth: AEDO NARVAEZ NICOLLE 28-04-00.jpg
# Copiado a milk-teeth: AEDO PINO EMILIA  (2).jpg
# Copiado a permanent-teeth: AEDO PINO EMILIA.jpg
# Copiado a permanent-teeth: AEDO SALINAS ELIAM  (1).jpg
# Copiado a permanent-teeth: AEDO SALINAS ELIAM  (1)_1.jpg
# Copiado a milk-teeth: AEDO SALINAS ELIAM (2).jpg
# Copiado a milk-teeth: AEDO SALINAS ELIAM (2)_1.jpg
# Copiado a milk-teeth: AEDO SALINAS ELIAM.jpg
# Copiado a permanent-teeth: AGUAYO BUCETA LUCCIANO.jpg
# Copiado a permanent-teeth: AGUAYO MUÑOZ NOELIA  (1).jpg
# Copiado a permanent-teeth: AGUAYO MUÑOZ NOELIA  (1)_1.jpg
# Copiado a permanent-teeth: AGUAYO VARELA BRENDA.jpg
# Copiado a permanent-teeth: AGUERO AYAQUINTUY SOFIA  (2).jpg
# Copiado a permanent-teeth: AGUERO AYAQUINTUY SOFIA  (2)_1.jpg
# Copiado a permanent-teeth: AGUILAR BECERRA PAULA 01-11-06 (2).jpg
# Copiado a permanent-teeth: AGUILAR REYDET MARCELO 20-08-02.jpg
# Copiado a permanent-teeth: AGUILEF SAN MARTIN EMILIA (2).jpg
# Copiado a permanent-teeth: AGUILEF SAN MARTIN EMILIA.jpg
# Copiado a milk-teeth: AGUILERA OBREQUE ANTONELLA.jpg
# Copiado a milk-teeth: AGUILERA OBREQUE ANTONELLA_1.jpg
# Copiado a permanent-teeth: AGUILERA SASTRE_A_20040124_77515704_1.jpg
# Copiado a milk-teeth: AGURTO ESPINOZA CRISTOFER.jpg
# Copiado a milk-teeth: AGURTO ESPINOZA CRISTOFER_1.jpg
# Copiado a milk-teeth: AGURTO ESPINOZA CRISTOFER_2.jpg
# Copiado a permanent-teeth: AGURTO HUILCAL SARA 07-01-04.jpg
# Copiado a milk-teeth: ALARCON CALLUMAN CRISTIAN  (1).jpg
# Copiado a milk-teeth: ALARCON CALLUMAN CRISTIAN  (1)_1.jpg
# Copiado a permanent-teeth: ALARCON CORTEZ CLAUDIO (1).jpg
# Copiado a permanent-teeth: ALARCON CORTEZ CLAUDIO.jpg
# Copiado a milk-teeth: ALARCON DE LA FUENTE MARTIN 02-06-09  (2).jpg
# Copiado a milk-teeth: ALARCON DE LA FUENTE MARTIN PAN.jpg
# Copiado a milk-teeth: ALARCON DE LA FUENTE MARTIN.jpg
# Copiado a permanent-teeth: ALARCON FUENTES ESPERANZA.jpg
# Copiado a permanent-teeth: ALARCON FUENTES ESPERANZA_1.jpg
# Copiado a permanent-teeth: ALARCON FUENTES ESPERANZA_2.jpg
# Copiado a permanent-teeth: ALARCON FUENTES ESPERANZA_3.jpg
# Copiado a permanent-teeth: ALARCON HERNANDEZ FRANCO  (2).jpg
# Copiado a permanent-teeth: ALARCON HERNANDEZ FRANCO  (2)_1.jpg
# Copiado a permanent-teeth: ALARCON LEAL FLORENCIA (2).jpg
# Copiado a permanent-teeth: ALARCON NAHUELHUAL NATALIA  (1).jpg
# Copiado a permanent-teeth: ALARCON NAHUELHUAN NATALIA.jpg
# Copiado a permanent-teeth: ALARCON NAHUELHUAN NATALIA_1.jpg
# Copiado a permanent-teeth: ALARCON PINILLA SOFIA (1).jpg
# Copiado a permanent-teeth: ALARCON PINILLA SOFIA.jpg
# Copiado a permanent-teeth: ALARCON PINILLA SOFIA_1.jpg
# Copiado a milk-teeth: ALARCON SAEZ ANAIS  (2).jpg
# Copiado a milk-teeth: ALARCON SAEZ ANAIS (2).jpg
# Copiado a permanent-teeth: ALBINO MUÑOZ AYELEN.jpg
# Copiado a permanent-teeth: ALBINO MUÑOZ AYELEN_1.jpg
# Copiado a permanent-teeth: ALBORNOZ CELEDON CONSTANZA.jpg
# Copiado a permanent-teeth: ALBORNOZ VILUBRON  FRANCISCA.jpg
# Copiado a permanent-teeth: ALBORNOZ VILUBRON ANGELA.jpg
# Copiado a permanent-teeth: ALBORNOZ VILUGRON ANGELA 27-10-03.jpg
# Copiado a permanent-teeth: ALBORNOZ VILUGRON ANGELA.jpg
# Copiado a permanent-teeth: ALBORNOZ VILUGRON ANGELA_1.jpg
# Copiado a permanent-teeth: ALBORNOZ VILUGRON ANGELA_2.jpg
# Copiado a permanent-teeth: ALBORNOZ VILUGRON FRANCISCA.jpg
# Copiado a permanent-teeth: ALBORNOZ VILUGRON FRANCISCA07-02-08.jpg
# Copiado a permanent-teeth: ALIANTE CARTES RACHEL.jpg
# Copiado a permanent-teeth: ALIANTE CARTES RACHEL_1.jpg
# Copiado a permanent-teeth: ALTAMIRANO CARRASCO ANTONELLA  (1).jpg
# Copiado a permanent-teeth: ALTAMIRANO CARRASCO ANTONELLA  (1)_1.jpg
# Copiado a permanent-teeth: ALTAMIRANO CHAVEZ JENIFER.jpg
# Copiado a permanent-teeth: ALTAMIRANO MENDEZ PIA (2).jpg
# Copiado a milk-teeth: ALVARADO ALVARADO IRIS 24-11-08.jpg
# Copiado a permanent-teeth: ALVARADO ALVARADO IRIS.jpg
# Copiado a permanent-teeth: ALVARADO ALVARADO IRIS_1.jpg
# Copiado a permanent-teeth: ALVARADO CARRERA SCARLETH 08-12-05.jpg
# Copiado a permanent-teeth: ALVAREZ ACUÑA DANIELA.jpg
# Copiado a permanent-teeth: ALVAREZ ACUÑA DANIELA_1.jpg
# Copiado a permanent-teeth: ALVAREZ BRACAMONTE FERNANDO  (1).jpg
# Copiado a permanent-teeth: ALVAREZ BRACAMONTE FERNANDO  (1)_1.jpg
# Copiado a permanent-teeth: ALVAREZ BRACAMONTE FERNANDO (1).jpg
# Copiado a permanent-teeth: ALVAREZ BRACAMONTE FRANCO  (2).jpg
# Copiado a permanent-teeth: ALVAREZ BRACAMONTE FRANCO  (2)_1.jpg
# Copiado a permanent-teeth: ALVAREZ BRACAMONTES FRANCO.jpg
# Copiado a permanent-teeth: ALVAREZ BRACAMONTES FRANCO_1.jpg
# Copiado a milk-teeth: ALVAREZ HIGUIERA MARVIN  (1).jpg
# Copiado a milk-teeth: ALVAREZ HIGUIERA MARVIN  (1)_1.jpg
# Copiado a permanent-teeth: ALVAREZ L PAULA.jpg
# Copiado a permanent-teeth: ALVAREZ LEUFUMAN PAULA 25-09-00.jpg
# Copiado a permanent-teeth: ALVAREZ MELLADO FERNANDA (2).jpg
# Copiado a permanent-teeth: ALVAREZ MELLADO FERNANDA (3).jpg
# Copiado a permanent-teeth: ALVAREZ SOTO JOAQUIN 2.jpg
# Copiado a permanent-teeth: ALVAREZ SOTO JOAQUIN 2_1.jpg
# Copiado a milk-teeth: ALVAREZ TORRES SOFIA  19-01-05.jpg
# Copiado a permanent-teeth: AMARO COFRE FELIPE 29-03-2001 (2).jpg
# Copiado a permanent-teeth: AMARO COFRE FELIPE.jpg
# Copiado a permanent-teeth: AMARO COFRE FELIPE_1.jpg
# Copiado a permanent-teeth: AMARO PACTER ALBERT 15-09-06 (1).jpg
# Copiado a permanent-teeth: AMARO PACTER ALBERT.jpg
# Copiado a milk-teeth: AMARO PACTER ROMINA 26-10-12.jpg
# Copiado a milk-teeth: ANABALON GALDAMES  MONSERRATT (1).jpg
# Copiado a milk-teeth: ANABALON GALDAMES  MONSERRATT (1)_1.jpg
# Copiado a permanent-teeth: ANCALEF DUGUETT IGNACIA.jpg
# Copiado a permanent-teeth: ANCAO FIGUEROA EVA.jpg
# Copiado a permanent-teeth: ANCEL HUAIQUILAF DANIELA 08-07-10 (2).jpg
# Copiado a permanent-teeth: ANCEL HUAIQUILAF DANIELA.jpg
# Copiado a permanent-teeth: ANCEL HUAQUILAF DANIELA.jpg
# Copiado a permanent-teeth: ANCEL HUAQUILAF DANIELA_1.jpg
# Copiado a milk-teeth: ANDANA MEDINA KEBHIN 04-10-01.jpg
# Copiado a permanent-teeth: ANDERS VIVANCO GUILLERMO (2).jpg
# Copiado a permanent-teeth: ANDERS VIVANCO GUILLERMO (2)_1.jpg
# Copiado a permanent-teeth: ANDRADE CABEZAS MELISSA.jpg
# Copiado a permanent-teeth: ANDRADE OYARCE FERNANDA 15-07-2005 (1).jpg
# Copiado a permanent-teeth: ANGELA JORQUERA.jpg
# Copiado a permanent-teeth: ANIÑIR SANHUEZA CESAR 12-08-2000 (1).jpg
# Copiado a permanent-teeth: ANIÑIR TRECANAO JAVIERA 23-06-03.jpg
# Copiado a permanent-teeth: ANIÑIR TRECANAO JAVIERA.jpg
# Copiado a permanent-teeth: ANONI CASTRO DIEGO 22-01-04.jpg
# Copiado a permanent-teeth: ANTIMIL CUAPIL BARBARA.jpg
# Copiado a permanent-teeth: ANTIMIL CURAPIL BARBARA 29-09-02.jpg
# Copiado a permanent-teeth: ANTIMIL ROMERO CAMILA.jpg
# Copiado a milk-teeth: ANTIMIL ROMERO FERNANDA (2).jpg
# Copiado a permanent-teeth: ANTINAO AMAYA JESICA.jpg
# Copiado a permanent-teeth: ANTINAO NECULQUEO FELIPE 23-10-01.jpg
# Copiado a permanent-teeth: ANTINAO NECULQUEO FELIPE.jpg
# Copiado a permanent-teeth: ANTINAO NECULQUEO FELIPE_1.jpg
# Copiado a permanent-teeth: ANTINAO NECULQUEO FELIPE_2.jpg
# Copiado a permanent-teeth: ANTINAO TRAIPE KATALINA  (1).jpg
# Copiado a permanent-teeth: ANTINAO TRAIPE KATALINA  (1)_1.jpg
# Copiado a permanent-teeth: ANTINAO TRAIPE ROCIO (2).jpg
# Copiado a permanent-teeth: ANTIQUERA MAZA NATALIA 24-05-2002 (1).jpg
# Copiado a permanent-teeth: ANTIVIL PARRA DIEGO 30-05-03.jpg
# Copiado a permanent-teeth: ANTIVIL PARRA DIEGO.jpg
# Copiado a permanent-teeth: ANTIVIL PARRA DIEGO_1.jpg
# Copiado a permanent-teeth: ANTIVIL PARRA_D_20030530_325591848_1.jpg
# Copiado a permanent-teeth: ARANDA ARIAS KARIN.jpg
# Copiado a permanent-teeth: ARANDA SAN MARTIN FABIAN 26-10-00.jpg
# Copiado a milk-teeth: ARANEDA CABRERA VICENTE.jpg
# Copiado a milk-teeth: ARANEDA CABRERA VICENTE_1.jpg
# Copiado a milk-teeth: ARANEDA CABRERA VICENTE_2.jpg
# Copiado a permanent-teeth: ARANEDA CACERES VALENTINA.jpg
# Copiado a permanent-teeth: ARANEDA CACERES VALENTINA_1.jpg
# Copiado a permanent-teeth: ARANEDA CACERES VALENTINA_2.jpg
# Copiado a permanent-teeth: ARANEDA ESCOBAR BENJAMIN.jpg
# Copiado a milk-teeth: ARANGO CARRASCO ESEQUIEL 03-05-10 (1).jpg
# Copiado a permanent-teeth: ARANGUIZ ELGUETA KRISHNA (2).jpg
# Copiado a permanent-teeth: ARANGUIZ ELGUETA KRISHNA.jpg
# Copiado a permanent-teeth: ARAUJO ESPINOZA FERNANDO 05-03-05.jpg
# Copiado a permanent-teeth: ARAVENA RIQUELME MARTIN.jpg
# Copiado a permanent-teeth: ARAVENA RIVERA FELIPE.jpg
# Copiado a permanent-teeth: ARAYA ANINAO TABITA 23-03-04.jpg
# Copiado a permanent-teeth: ARAYA MONTECINOS NOEMI (2).jpg
# Copiado a permanent-teeth: ARAYA MONTECINOS NOEMI 14-12-02 (2).jpg
# Copiado a permanent-teeth: ARAYA MONTECINOS NOEMI.jpg
# Copiado a permanent-teeth: ARCE TORRES BERENICE 28-04-04 (2).jpg
# Copiado a permanent-teeth: ARCE TORRES ROCIO  (2).jpg
# Copiado a permanent-teeth: ARCE TORRES ROCIO 10-11-02 (1).jpg
# Copiado a permanent-teeth: ARCE VALLEJOS MATILDA.jpg
# Copiado a permanent-teeth: ARCE VALLEJOS MATILDA_1.jpg
# Copiado a permanent-teeth: ARDILES HERNANDEZ DAMARIS  (2).jpg
# Copiado a permanent-teeth: ARDILES HERNANDEZ DAMARIS  (2)_1.jpg
# Copiado a permanent-teeth: ARELLANO VIDAL RENATO.jpg
# Copiado a permanent-teeth: ARIAS CALFIN HENRY.jpg
# Copiado a milk-teeth: ARIAS GUAJARDO AGUSTINA.jpg
# Copiado a permanent-teeth: ARIAS GUAJARDO FRANCO (2).jpg
# Copiado a milk-teeth: ARIAS REYES LAURA  (2).jpg
# Copiado a milk-teeth: ARIAS REYES LAURA (2).jpg
# Copiado a milk-teeth: ARIAS REYES LAURA.jpg
# Copiado a permanent-teeth: ARIAS SEPULVEDA ALEXIA.jpg
# Copiado a milk-teeth: ARIAS SEPULVEDA ALEXIA_1.jpg
# Copiado a milk-teeth: ARIAS SEPULVEDA ALEXIA_2.jpg
# Copiado a milk-teeth: AROCA MORA CAMILA.jpg
# Copiado a milk-teeth: AROCA MORA CAMILA_1.jpg
# Copiado a permanent-teeth: ARRATIA ZENTENO PERLA 17-02-03.jpg
# Copiado a permanent-teeth: ARRATIA ZENTENO PERLA.jpg
# Copiado a permanent-teeth: ARRATIA ZENTENO PERLA_1.jpg
# Copiado a permanent-teeth: ARRATIA ZENTENO PERLA_2.jpg
# Copiado a permanent-teeth: ARREPOL JARA SHARON 16-02-01.jpg
# Copiado a permanent-teeth: ARRIAGADA GUTIERREZ MARTIN.jpg
# Copiado a permanent-teeth: ARRIAGADA MUÑOZ AMANDA  (2).jpg
# Copiado a permanent-teeth: ARRIAGADA MUÑOZ AMANDA  (2)_1.jpg
# Copiado a permanent-teeth: ARRIAGADA MUÑOZ AMANDA.jpg
# Copiado a permanent-teeth: ARRIAGADA MUÑOZ AMANDA_1.jpg
# Copiado a permanent-teeth: ARRIAGADA SANTANDER RODRIGO.jpg
# Copiado a permanent-teeth: ARRIAGADA SOTO LUIS.jpg
# Copiado a permanent-teeth: ARRIAGADA SOTO LUIS_1.jpg
# Copiado a permanent-teeth: ARRIAGADA SOTO LUIS_2.jpg
# Copiado a permanent-teeth: ARRIAGADA SOTO LUIS_3.jpg
# Copiado a permanent-teeth: ARROYO URRUTIA ANDRES (1).jpg
# Copiado a permanent-teeth: ARROYO URRUTIA ANDRES (1)_1.jpg
# Copiado a permanent-teeth: ARROYO URRUTIA DIEGO  (2).jpg
# Copiado a permanent-teeth: ARROYO URRUTIA DIEGO  (2)_1.jpg
# Copiado a milk-teeth: ARTIGAS PICUNCHE MILLARAY.jpg
# Copiado a permanent-teeth: ASTETE ASTETE KATERINE 24-08-01.jpg
# Copiado a milk-teeth: ASTUDILLO ANCAMIL ENERTINA.jpg
# Copiado a permanent-teeth: ASTUDILLO ANCAMIL ERNESTINA  25-12-05 (2).jpg
# Copiado a permanent-teeth: ASTUDILLO ANCAMIL ERNESTINA.jpg
# Copiado a permanent-teeth: ASTUDILLO ANCAMIL ERNESTINA_1.jpg
# Copiado a permanent-teeth: ASTUDILLO CURAMIL JAVIERA 17-01-2009  (1).jpg
# Copiado a permanent-teeth: ASTUDILLO CURAMIL JAVIERA.jpg
# Copiado a permanent-teeth: ASTUDILLO CURAMIL MARTINA (2).jpg
# Copiado a permanent-teeth: ASTUDILLO CURAMIL YADIRA.jpg
# Copiado a permanent-teeth: ASTUDILLO ULLOA JELEN (2).jpg
# Copiado a permanent-teeth: AVILA AGUAYO LYZ.jpg
# Copiado a permanent-teeth: AZOCAR GALLEGOS LUCAS.jpg
# Copiado a permanent-teeth: AZOCAR GALLEGOS LUCAS_1.jpg
# Copiado a permanent-teeth: AZOCAR GALLEGOS LUCAS_2.jpg
# Copiado a permanent-teeth: AZOCAR GALLEGOS LUCAS_3.jpg
# Copiado a permanent-teeth: AZOCAR GALLEGOS LUCAS_4.jpg
# Copiado a milk-teeth: BADILLA CASTRO CATALINA.jpg
# Copiado a permanent-teeth: BAEZ NOCHES JOAQUIN 22-02-99.jpg
# Copiado a permanent-teeth: BAEZA FIGUEROA ERIKA 10-09-99.jpg
# Copiado a permanent-teeth: BAEZA GODOY CRISTOBAL  (1).jpg
# Copiado a permanent-teeth: BAEZA GODOY CRISTOBAL  (1)_1.jpg
# Copiado a permanent-teeth: BAEZA GODOY MATIAS  (1).jpg
# Copiado a permanent-teeth: BAEZA GODOY MATIAS  (1)_1.jpg
# Copiado a permanent-teeth: BAEZA GODOY MATIAS  (4).jpg
# Copiado a permanent-teeth: BAEZA GODOY MATIAS  (4)_1.jpg
# Copiado a permanent-teeth: BAEZA GODOY MATIAS.jpg
# Copiado a permanent-teeth: BAHAMONDES MANQUILEF BELEN.jpg
# Copiado a permanent-teeth: BAHAMONDEZ AVENDAÑO VALERIA 11-02-06.jpg
# Copiado a permanent-teeth: BAIER PALACIOS MARTINA.jpg
# Copiado a permanent-teeth: BANEGAS GARCES FLORENCIA 02-02-03.jpg
# Copiado a milk-teeth: BARAHONA  OPAZO FRANCISCA 30-05-05.jpg
# Copiado a permanent-teeth: BARRA BASCUR MARTINA 17-10-05 (1).jpg
# Copiado a permanent-teeth: BARRA BASCUR MARTINA.jpg
# Copiado a permanent-teeth: BARRA CASTILLO MARCELO 05-09-03 (2).jpg
# Copiado a permanent-teeth: BARRA ITURRA ABEL.jpg
# Copiado a permanent-teeth: BARRA ITURRA ABEL_1.jpg
# Copiado a permanent-teeth: BARRA ITURRA ABEL_2.jpg
# Copiado a permanent-teeth: BARRA MANRIQUEZ TOMAS  (2).jpg
# Copiado a permanent-teeth: BARRA ROBLES FRANCISCA 10-12-07.jpg
# Copiado a permanent-teeth: BARRA RUIZ RAYHAN.jpg
# Copiado a permanent-teeth: BARRA RUIZ RAYHAN_1.jpg
# Copiado a milk-teeth: BARRAGAN BARRERA MAITE (2).jpg
# Copiado a milk-teeth: BARRAGAN BARRERA MAITE (2)_1.jpg
# Copiado a milk-teeth: BARRAGAN BARRERA MAITE.jpg
# Copiado a milk-teeth: BARRAGAN BARRERA MAITE_1.jpg
# Copiado a milk-teeth: BARRAGAN BARRERA MAITE_2.jpg
# Copiado a permanent-teeth: BARRALES SAN MARTIN YASNA 28-09-20.jpg
# Copiado a permanent-teeth: BARRERA GONZALEZ AMANDA  (1).jpg
# Copiado a permanent-teeth: BARRERA GONZALEZ AMANDA  (1)_1.jpg
# Copiado a permanent-teeth: BARRERA LOPEZ CONSTANZA 26-12-01.jpg
# Copiado a permanent-teeth: BARRERA LOPEZ CONSTANZA.jpg
# Copiado a permanent-teeth: BARRERA OBREQUE ALONSO.jpg
# Copiado a permanent-teeth: BARRERA OBREQUE SOFIA.jpg
# Copiado a milk-teeth: BARRIA MUÑOZ AGUSTIN.jpg
# Copiado a permanent-teeth: BARRIENTOS HIDALGO CARLOS  (3).jpg
# Copiado a permanent-teeth: BARRIENTOS HIDALGO JUAN PABLO (1).jpg
# Copiado a permanent-teeth: BARRIENTOS HIDALGO JUAN PABLO.jpg
# Copiado a permanent-teeth: BARRIENTOS HIDALGO JUAN PABLO_1.jpg
# Copiado a permanent-teeth: BARRIENTOS VELASQUEZ FERNANDA  (2).jpg
# Copiado a permanent-teeth: BARRIENTOS VELASQUEZ FERNANDA  (2)_1.jpg
# Copiado a permanent-teeth: BARRIGA LAGOS CATALINA  (2).jpg
# Copiado a permanent-teeth: BARRIGA NAHUELCHEO ANGELICA.jpg
# Copiado a permanent-teeth: BARRIGA NAHUELCHEO ANGELICA_1.jpg
# Copiado a permanent-teeth: BARRIGA NUÑEZ ALEJANDRA (1).jpg
# Copiado a permanent-teeth: BARRIGA NUÑEZ ALEJANDRA.jpg
# Copiado a permanent-teeth: BARRIGA NUÑEZ ALEJANDRA_1.jpg
# Copiado a permanent-teeth: BARROS VALDEBENITO ANTONELLA.jpg
# Copiado a permanent-teeth: BARROS VALDEBENITO FLORENCIA.jpg
# Copiado a permanent-teeth: BASLY PIRUL DANIEL 06-02-05.jpg
# Copiado a permanent-teeth: BASLY PIRUL DANIEL.jpg
# Copiado a permanent-teeth: BASLY PIRUL DANIEL_1.jpg
# Copiado a permanent-teeth: BASTIAS BRAVO NICOLAS 09-08-1998.jpg
# Copiado a permanent-teeth: BASTIAS POZAS DIEGO 02-06-03.jpg
# Copiado a permanent-teeth: BASTIAS POZAS DIEGO.jpg
# Copiado a permanent-teeth: BASUALTO TRUJILLO CAROLINA 26-01-96.jpg
# Copiado a permanent-teeth: BAZA RAÑILAO FERNANDA (2).jpg
# Copiado a permanent-teeth: BAZA RAÑILAO FERNANDA.jpg
# Copiado a permanent-teeth: BAZA RAÑINAO BENJAMIN.jpg
# Copiado a permanent-teeth: BAZA RAÑINAO BENJAMIN_1.jpg
# Copiado a permanent-teeth: BAZA RAÑINAO BENJAMIN_2.jpg
# Copiado a permanent-teeth: BECERRA FLORES JUVENAL.jpg
# Copiado a permanent-teeth: BECERRA FLORES JUVENAL_1.jpg
# Copiado a milk-teeth: BECERRA FLORES JUVENAL_2.jpg
# Copiado a permanent-teeth: BECERRA FLORES JUVENAL_3.jpg
# Copiado a milk-teeth: BECERRA FLORES JUVENAL_4.jpg
# Copiado a permanent-teeth: BELLO ALARCON BENJAMIN 29-12-00.jpg
# Copiado a permanent-teeth: BELLO ARMONA ANDRÉS 17-02-1977.jpg
# Copiado a permanent-teeth: BELLO AVILA NICOLAS.jpg
# Copiado a permanent-teeth: BELLO AVILA NICOLAS_1.jpg
# Copiado a milk-teeth: BELLO BENAVIDES  CHRISTOPHER.jpg
# Copiado a milk-teeth: BELLO BENAVIDES CRISTOFER.jpg
# Copiado a milk-teeth: BELLO BENAVIDES CRISTOFER_1.jpg
# Copiado a milk-teeth: BELLO BENAVIDES CRISTOPFER.jpg
# Copiado a permanent-teeth: BELLO BENAVIDES CRISTOPFER_1.jpg
# Copiado a milk-teeth: BELLO BENAVIDES CRISTOPFER_2.jpg
# Copiado a permanent-teeth: BELLO BENAVIDES NAZARETH.jpg
# Copiado a milk-teeth: BELLO BENAVIES CRISTOPHER.jpg
# Copiado a permanent-teeth: BELLO NORAMBUENA ANDRES 18-08-04.jpg
# Copiado a permanent-teeth: BELLO NORAMBUENA ROCIO  (2).jpg
# Copiado a permanent-teeth: BELLO NORAMBUENA ROCIO.jpg
# Copiado a permanent-teeth: BELLO NORAMBUENA ROCIO_1.jpg
# Copiado a permanent-teeth: BELLO RECABARREN FERNANDA 23-09-05.jpg
# Copiado a permanent-teeth: BELLO RECABARREN FERNANDA.jpg
# Copiado a permanent-teeth: BELMAR BRAVO MARTINA (2).jpg
# Copiado a permanent-teeth: BELMAR BRAVO MARTINA.jpg
# Copiado a milk-teeth: BELTRAN MILA BENJAMIN.jpg
# Copiado a milk-teeth: BELTRAN MILA BENJAMIN_1.jpg
# Copiado a milk-teeth: BELTRAN MILA SOFIA  (1).jpg
# Copiado a milk-teeth: BELTRAN MILA SOFIA  (1)_1.jpg
# Copiado a permanent-teeth: BELTRAN NEIRA FERNANDA 05-07-2005 (4).jpg
# Copiado a permanent-teeth: BELTRAN NEIRA FERNANDA.jpg
# Copiado a permanent-teeth: BELTRAN NEIRA YASMIN 04-06-01.jpg
# Copiado a permanent-teeth: BELTRAN RAMOS KATHERINE 31-01-03.jpg
# Copiado a milk-teeth: BELTRAN ROJAS ANALIE.jpg
# Copiado a milk-teeth: BELTRAN ROJAS ANALIE_1.jpg
# Copiado a milk-teeth: BELTRAN ROJAS ANALIE_2.jpg
# Copiado a milk-teeth: BELTRAN ROJAS ANALIE_3.jpg
# Copiado a permanent-teeth: BELTRAN SALAMANCA DANIEL.jpg
# Copiado a permanent-teeth: BENAVIDES CALFULAF NOEMI.jpg
# Copiado a permanent-teeth: BENAVIDES CALFULAF NOEMI_1.jpg
# Copiado a permanent-teeth: BENAVIDES CALFULAF NOEMY  (1).jpg
# Copiado a permanent-teeth: BENAVIDES CALFULAF NOEMY  (1)_1.jpg
# Copiado a milk-teeth: BENAVIDES LIZAMA JAVIER 05-09-09 (1).jpg
# Copiado a milk-teeth: BENAVIDES LIZAMA JAVIER.jpg
# Copiado a permanent-teeth: BENAVIDES TREHUELEN JAVIERA.jpg
# Copiado a permanent-teeth: BENAVIDES TREHUELEN JAVIERA_1.jpg
# Copiado a permanent-teeth: BENAVIDEZ LIZAMA JAVIER  (1).jpg
# Copiado a permanent-teeth: BENAVIDEZ LIZAMA JAVIER  (1)_1.jpg
# Copiado a permanent-teeth: BERNAL PINTO GONZALO 16-06-00.jpg
# Copiado a permanent-teeth: BERNT LLANCAMAN CATALINA  (2).jpg
# Copiado a permanent-teeth: BETANCOURT ESPARZA EMILIA.jpg
# Copiado a permanent-teeth: BETANCOURT SALAS GRACIELA (2).jpg
# Copiado a permanent-teeth: BETANCOURT SALAS GRACIELA.jpg
# Copiado a permanent-teeth: BEÑALDO CATALAN SAMUEL 29-02-00.jpg
# Copiado a permanent-teeth: BINIMELIS OSSES DEMIAN.jpg
# Copiado a milk-teeth: BIOLLEY MUÑOZ THOMAS  (1).jpg
# Copiado a milk-teeth: BIZAMA COLLIO DIANA.jpg
# Copiado a milk-teeth: BIZAMA COLLIO DIANA_1.jpg
# Copiado a milk-teeth: BIZAMA FIGUEROA TAMARA.jpg
# Copiado a permanent-teeth: BLANCK ULLOA EVOLETTE.jpg
# Copiado a permanent-teeth: BLANCK ULLOA EVOLETTE_1.jpg
# Copiado a milk-teeth: BLANCK ULLOA EVOLLETTE (2).jpg
# Copiado a milk-teeth: BLANCK ULLOA EVOLLETTE.jpg
# Copiado a permanent-teeth: BLANCO ARANEDA CRISTOBAL  07-08-08 (2).jpg
# Copiado a permanent-teeth: BLANCO ARANEDA CRISTOBAL.jpg
# Copiado a permanent-teeth: BLANCO ARANEDA CRISTOBAL_1.jpg
# Copiado a permanent-teeth: BLAS HUENUPI LEONARDO (2).jpg
# Copiado a permanent-teeth: BLAS HUENUPI LEONARDO (2)_1.jpg
# Copiado a permanent-teeth: BLASS HUENUPI LEONARDO (2).jpg
# Copiado a permanent-teeth: BLASS HUENUPI LEONARDO 3.jpg
# Copiado a permanent-teeth: BLASS HUENUPI LEONARDO.jpg
# Copiado a permanent-teeth: BLASS HUENUPI LEONARDO_1.jpg
# Copiado a permanent-teeth: BLUAS GUZMAN EDISON.jpg
# Copiado a permanent-teeth: BLUAS GUZMAN EDISON_1.jpg
# Copiado a permanent-teeth: BLUAS GUZMAN_A_20040121_72737896_1.jpg
# Copiado a milk-teeth: BLUAS HIDALGO ISIDORA 10-11-09.jpg
# Copiado a permanent-teeth: BLUAS HIDALGO ISIDORA.jpg
# Copiado a permanent-teeth: BLUAS HIDALGO PABLA.jpg
# Copiado a milk-teeth: BOOCK MANRIQUEZ EMILIA.jpg
# Copiado a milk-teeth: BORQUEZ ALMONACID ISABELLA (2).jpg
# Copiado a milk-teeth: BORQUEZ ALMONACID ISABELLA (2)_1.jpg
# Copiado a permanent-teeth: BOUNIOT HUAQUIMIL MAXIMILIANO.jpg
# Copiado a permanent-teeth: BOUNIOT PEREZ SOFIA 26-11-01.jpg
# Copiado a permanent-teeth: BOUNIOT PEREZ SOFIA.jpg
# Copiado a permanent-teeth: BRAUKMAN CASTILLO JOSEFA.jpg
# Copiado a permanent-teeth: BRAVO GOMEZ AMARO  (2).jpg
# Copiado a permanent-teeth: BRAVO GOMEZ AMARO  (2)_1.jpg
# Copiado a milk-teeth: BRAVO PACHECO LIA  (2).jpg
# Copiado a milk-teeth: BRAVO PACHECO LIA  (2)_1.jpg
# Copiado a permanent-teeth: BRAVO PACHECO LIA.jpg
# Copiado a permanent-teeth: BRAVO PACHECO LIA_1.jpg
# Copiado a permanent-teeth: BRAVO VENEGAS CRISTINA.jpg
# Copiado a permanent-teeth: BRAVO VENEGAS CRISTINA_1.jpg
# Copiado a milk-teeth: BRICEÑO PALENCIA ABRIL.jpg
# Copiado a permanent-teeth: BRICEÑO PALENCIA ABRIL_1.jpg
# Copiado a permanent-teeth: BRICEÑO PALENCIA ABRIL_2.jpg
# Copiado a milk-teeth: BRIONES BRAVO MAITE  (2).jpg
# Copiado a milk-teeth: BRIONES BRAVO MAITE  (2)_1.jpg
# Copiado a milk-teeth: BRIONES BRAVO PASCAL  (2).jpg
# Copiado a milk-teeth: BRIONES BRAVO PASCAL  (2)_1.jpg
# Copiado a permanent-teeth: BRUN QUILACAN BARBARA 17-05-04 (2).jpg
# Copiado a permanent-teeth: BRUNA RIVAS YERICK 01-02-07 (2).jpg
# Copiado a permanent-teeth: BRUNA RIVAS YERIK.jpg
# Copiado a milk-teeth: BUCHI VILLEGAS ELENA (2).jpg
# Copiado a milk-teeth: BUCHI VILLEGAS ELENA (2)_1.jpg
# Copiado a permanent-teeth: BURGOS BURGOS GABRIEL 05-10-20.jpg
# Copiado a permanent-teeth: BURGOS BURGOS GABRIEL.jpg
# Copiado a milk-teeth: BURGOS CAYUQUEO MIA  (2).jpg
# Copiado a milk-teeth: BURGOS CAYUQUEO MIA  (2)_1.jpg
# Copiado a permanent-teeth: BURGOS FUENTEALBA FABIOLA 11-01-97 (2).jpg
# Copiado a permanent-teeth: BURGOS GARCES SARAY (2).jpg
# Copiado a milk-teeth: BURGOS JARAMILLO AMBAR  (2).jpg
# Copiado a milk-teeth: BURGOS JARAMILLO AMBAR  (2)_1.jpg
# Copiado a permanent-teeth: BURGOS JOFRE CELEZTE  (2).jpg
# Copiado a permanent-teeth: BURGOS JOFRE CELEZTE.jpg
# Copiado a permanent-teeth: BURGOS JOFRE CELEZTE_1.jpg
# Copiado a permanent-teeth: BURGOS JOFRE YANNELA  (1).jpg
# Copiado a permanent-teeth: BURGOS MORALES CRISTOBAL  (1).jpg
# Copiado a permanent-teeth: BURGOS MORALES CRISTOBAL  (1)_1.jpg
# Copiado a permanent-teeth: BURGOS QUIÑELEF INES.jpg
# Copiado a permanent-teeth: BURGOS QUIÑELEN INES.jpg
# Copiado a permanent-teeth: BURGOS ROMERO MOISES  (1).jpg
# Copiado a permanent-teeth: BURGOS SEPULVEDA ANGELO  (2).jpg
# Copiado a permanent-teeth: BURGOS SEPULVEDA ANGELO  (2)_1.jpg
# Copiado a permanent-teeth: BURGOS SEPULVEDA ANGELO (2).jpg
# Copiado a milk-teeth: BUSTAMANTE ECHEVERRIA JULIETA  (2).jpg
# Copiado a milk-teeth: BUSTAMANTE ECHEVERRIA JULIETA  (2)_1.jpg
# Copiado a milk-teeth: BUSTAMANTE ECHEVERRIA JULIETA  (2)_2.jpg
# Copiado a permanent-teeth: BUSTAMANTE ZAVALA SOFIA  (1).jpg
# Copiado a permanent-teeth: BUSTAMANTE ZAVALA SOFIA  (1)_1.jpg
# Copiado a permanent-teeth: BUSTOS BLATTER ANITZY  (1).jpg
# Copiado a milk-teeth: BUSTOS BUSTOS MAXIMILIANO  (1).jpg
# Copiado a milk-teeth: BUSTOS BUSTOS MAXIMILIANO  (1)_1.jpg
# Copiado a milk-teeth: BUSTOS FARIAS VICTOR 04-07-07 (1).jpg
# Copiado a permanent-teeth: BUSTOS MARTIN ALEXANDER (2).jpg
# Copiado a permanent-teeth: BUSTOS MARTIN ALEXANDER.jpg
# Copiado a permanent-teeth: BUSTOS MARTIN ALEXANDER_1.jpg
# Copiado a permanent-teeth: BUSTOS MARTIN ALEXANDER_2.jpg
# Copiado a permanent-teeth: BUSTOS PEREZ JOAQUIN  (2).jpg
# Copiado a permanent-teeth: BUSTOS PEREZ JOAQUIN  (2)_1.jpg
# Copiado a permanent-teeth: BUSTOS RODRIGUEZ ISABELLA (1).jpg
# Copiado a permanent-teeth: BUSTOS RODRIGUEZ ISABELLA (1)_1.jpg
# Copiado a milk-teeth: BUSTOS RODRIGUEZ ISABELLA 24-11-12 (1).jpg
# Copiado a milk-teeth: BUSTOS RODRIGUEZ ISABELLA.jpg
# Copiado a permanent-teeth: BUSTOS VALERIA CAROLINA (2).jpg
# Copiado a permanent-teeth: BUSTOS VALERIA CAROLINA 02-04-2003  (2).jpg
# Copiado a permanent-teeth: BUSTOS VALERIA CAROLINA.jpg
# Copiado a permanent-teeth: CABEZA HERNANDEZ JAVIERA 10-02-07.jpg
# Copiado a permanent-teeth: CABEZAS FUENTES CONSTANZA.jpg
# Copiado a permanent-teeth: CABEZAS FUENTES TAMARA.jpg
# Copiado a permanent-teeth: CABEZAS MUÑOZ CRISTIAN  (1).jpg
# Copiado a permanent-teeth: CABEZAS MUÑOZ CRISTIAN  (1)_1.jpg
# Copiado a permanent-teeth: CABRERA CARRASCO FERNANDA.jpg
# Copiado a permanent-teeth: CABRERA CAYUPAN MAXIMILIANO.jpg
# Copiado a permanent-teeth: CABRERA CERDA GENESIS (2).jpg
# Copiado a permanent-teeth: CABRERA CERDA GENESIS.jpg
# Copiado a permanent-teeth: CABRERA CERDA GENESIS_1.jpg
# Copiado a permanent-teeth: CABRERA CERDA GENESIS_2.jpg
# Copiado a permanent-teeth: CABRERA CERDA GENESIS_3.jpg
# Copiado a milk-teeth: CABRERA GUERRERO AMANDA.jpg
# Copiado a milk-teeth: CABRERA GUERRERO AMANDA_1.jpg
# Copiado a milk-teeth: CABRERA GUERRERO AMANDA_2.jpg
# Copiado a milk-teeth: CABRERA GUERRERO JOSEFINA.jpg
# Copiado a milk-teeth: CABRERA GUERRERO JOSEFINA_1.jpg
# Copiado a milk-teeth: CABRERA GUERRERO JOSEFINA_2.jpg
# Copiado a milk-teeth: CABRERA GUERRERO JOSEFINA_3.jpg
# Copiado a permanent-teeth: CABRERA MALLEA CONSTANZA  (2).jpg
# Copiado a permanent-teeth: CABRERA MALLEA CONSTANZA 23-05-07 (2).jpg
# Copiado a permanent-teeth: CABRERA MALLEA DANIELA.jpg
# Copiado a permanent-teeth: CABRERA MALLEA DANIELA_1.jpg
# Copiado a milk-teeth: CABRERA MUÑOZ AMANDA.jpg
# Copiado a milk-teeth: CABRERA MUÑOZ AMANDA_1.jpg
# Copiado a permanent-teeth: CABRERA TORO BELEN PAN.jpg
# Copiado a permanent-teeth: CABRERA TORO BELEN.jpg
# Copiado a permanent-teeth: CABRERA ZURITA CRISTIAN 23-01-03.jpg
# Copiado a permanent-teeth: CABRERA ZURITA CRISTIAN 24-09-20.jpg
# Copiado a permanent-teeth: CABRERA ZURITA CRISTIAN.jpg
# Copiado a permanent-teeth: CACERES CARRILLO MAXIMILIANO.jpg
# Copiado a permanent-teeth: CACERES GUTIERREZ JAVIERA.jpg
# Copiado a milk-teeth: CACERES GUTIERREZ JAVIERA_1.jpg
# Copiado a permanent-teeth: CACERES GUTIERRREZ JAVIERA 06-02-06 (2).jpg
# Copiado a permanent-teeth: CACERES RIOS  JAVIERA 16-09-03 (2).jpg
# Copiado a permanent-teeth: CACERES RIOS JAVIERA.jpg
# Copiado a permanent-teeth: CACERES RIOS JAVIERA_1.jpg
# Copiado a permanent-teeth: CAIRE HUENCHUPAN FERNANDA (2).jpg
# Copiado a permanent-teeth: CALFIN CURILEN CATALINA.jpg
# Copiado a permanent-teeth: CALFIN CURILEN CATALINA_1.jpg
# Copiado a milk-teeth: CALFIO VILLAGRAN JUAN PABLO (2).jpg
# Copiado a permanent-teeth: CALFIÑIR EPULEF KATIA 06-03-03.jpg
# Copiado a permanent-teeth: CALFIÑIR ORELLANA MARTINA 05-10-20.jpg
# Copiado a milk-teeth: CALFIÑIR ORELLANA MARTINA.jpg
# Copiado a milk-teeth: CALFIÑIR ORELLANA MARTINA_1.jpg
# Copiado a milk-teeth: CALFIÑIR ORELLANA MARTINA_2.jpg
# Copiado a permanent-teeth: CALFIÑIR RAIN LEANDRO.jpg
# Copiado a permanent-teeth: CALFUCOY HUICHALAO PATRICIO  (2).jpg
# Copiado a permanent-teeth: CALFUCOY HUICHALAO PATRICIO (2).jpg
# Copiado a permanent-teeth: CALFUCOY HUICHALEO PATRICIO.jpg
# Copiado a permanent-teeth: CALFUCOY HUICHALEO PATRICIO_1.jpg
# Copiado a permanent-teeth: CALFULEO HUEICHA ANTONIA 21-01-06 (2).jpg
# Copiado a permanent-teeth: CALFULEO HUEICHA ANTONIA.jpg
# Copiado a permanent-teeth: CALFULEO HUEICHA ANTONIA_1.jpg
# Copiado a permanent-teeth: CALFULEO HUEICHA ANTONIA_2.jpg
# Copiado a permanent-teeth: CALFULEO HUEICHA JUAN  (2).jpg
# Copiado a permanent-teeth: CALFULEO HUEICHA JUAN  (2)_1.jpg
# Copiado a permanent-teeth: CALFULEO HUEICHAN ANTONIA.jpg
# Copiado a permanent-teeth: CALFULLAN BURGOS ANTONELLA (2).jpg
# Copiado a permanent-teeth: CALFULLAN BURGOS ANTONELLA.jpg
# Copiado a permanent-teeth: CALFULLAN BURGOS ANTONELLA_1.jpg
# Copiado a permanent-teeth: CALFUPAN ZAMBRANO NAYARETH.jpg
# Copiado a permanent-teeth: CALFUPAN ZAMBRANO NAYARETH_1.jpg
# Copiado a permanent-teeth: CALFUÑIR RAIN LEANDRO 14-03-04 (1).jpg
# Copiado a permanent-teeth: CALFUÑIR RAIN LEANDRO.jpg
# Copiado a milk-teeth: CALISTO CARRILLO CATALINA.jpg
# Copiado a permanent-teeth: CALISTO CARRILLO CATALINA_1.jpg
# Copiado a permanent-teeth: CALLUMAN SANDOVAL MAITANIA.jpg
# Copiado a permanent-teeth: CALVO MALIQUEO JAVIER (2).jpg
# Copiado a permanent-teeth: CAMPOS GAJARDO SAMUEL 27-10-07 (2).jpg
# Copiado a permanent-teeth: CAMPOS LICANQUEO JOAQUIN 10-03-97.jpg
# Copiado a permanent-teeth: CAMPOS MANRIQUEZ ANTONELLA (1).jpg
# Copiado a permanent-teeth: CAMPOS MANRIQUEZ TAMARA.jpg
# Copiado a permanent-teeth: CAMPOS MUÑOZ VICENTE.jpg
# Copiado a permanent-teeth: CAMPOS OPAZO ISABEL.jpg
# Copiado a permanent-teeth: CAMPOS PAILLAN ADOLFO.jpg
# Copiado a permanent-teeth: CAMPOS PAILLAN ADOLFO_1.jpg
# Copiado a permanent-teeth: CAMPOS PAILLAN ADOLFO_2.jpg
# Copiado a permanent-teeth: CAMPOS POBLETE LEONARDO.jpg
# Copiado a permanent-teeth: CAMPOS RIVERA CARLA  (2).jpg
# Copiado a permanent-teeth: CAMPOS RIVERA CARLA 09-01-06.jpg
# Copiado a permanent-teeth: CAMPOS VILLARROEL JAVIERA.jpg
# Copiado a permanent-teeth: CAMPOS ZAPATA ARVALDO 07-09-00.jpg
# Copiado a milk-teeth: CAMUS GUTIERREZ GABRIEL  (1).jpg
# Copiado a permanent-teeth: CANALES CARVAJAL CRISTOPHER 15-10-02.jpg
# Copiado a permanent-teeth: CANALES CARVAJAL CRISTOPHER.jpg
# Copiado a permanent-teeth: CANALES PARRA CONSTANZA.jpg
# Copiado a permanent-teeth: CANALES PEREZ ROBERTO 15-09-04 (1).jpg
# Copiado a permanent-teeth: CANALES PEREZ ROBERTO.jpg
# Copiado a permanent-teeth: CANALES PEREZ ROBERTO_1.jpg
# Copiado a permanent-teeth: CANALES PEREZ ROBERTO_2.jpg
# Copiado a permanent-teeth: CANDIA CATALAN  VICTORIA.jpg
# Copiado a permanent-teeth: CANDIA CATALAN MARIA PAZ (1).jpg
# Copiado a permanent-teeth: CANDIA GONZALEZ EXEQUIEL 01-03-2006 (2).jpg
# Copiado a permanent-teeth: CANDIA GONZALEZ WILLIAM.jpg
# Copiado a permanent-teeth: CANDIA GONZALEZ WILLIAM_1.jpg
# Copiado a permanent-teeth: CANDIA GONZALEZ WILLIAM_2.jpg
# Copiado a permanent-teeth: CANDIA PAVEZ MARTINA  (2).jpg
# Copiado a permanent-teeth: CANDIA PAVEZ MARTINA 03-01-2006 (2).jpg
# Copiado a permanent-teeth: CANDIA PAVEZ MARTINA.jpg
# Copiado a permanent-teeth: CANDIA PAVEZ MARTINA_1.jpg
# Copiado a permanent-teeth: CANDIA RAIN KUYEN 24-10-01.jpg
# Copiado a permanent-teeth: CANDIA ZAVALA MARIA PAZ (2).jpg
# Copiado a permanent-teeth: CANDIA ZAVALA MARÍA PAZ 26-01-05.jpg
# Copiado a permanent-teeth: CANIO JARA CATALINA 01-09-06.jpg
# Copiado a permanent-teeth: CANIO JARA CATALINA.jpg
# Copiado a permanent-teeth: CANIO JINEO RICARDO.jpg
# Copiado a permanent-teeth: CANIO JINEO RICARDO_1.jpg
# Copiado a permanent-teeth: CANIO JINEO RICARDO_2.jpg
# Copiado a permanent-teeth: CANIO JINEO TRINIDAD  (2).jpg
# Copiado a permanent-teeth: CANIO JINEO TRINIDAD  (2)_1.jpg
# Copiado a milk-teeth: CANIO REYES ANTONIA.jpg
# Copiado a milk-teeth: CANIO REYES ANTONIA_1.jpg
# Copiado a milk-teeth: CANUPI BURGOS ANIBAL 06-05-19.jpg
# Copiado a permanent-teeth: CANUPI BURGOS_A_20040506_74307392_1.jpg
# Copiado a permanent-teeth: CAQUILPAN CHIHUAICURA MATIAS (2).jpg
# Copiado a permanent-teeth: CAQUILPAN CHIHUAICURA MATIAS.jpg
# Copiado a milk-teeth: CARCAMO DIAZ CLAUDIO.jpg
# Copiado a milk-teeth: CARCAMO DIAZ CLAUDIO_1.jpg
# Copiado a permanent-teeth: CARDENAS AEDO MALENY  (2).jpg
# Copiado a permanent-teeth: CARDENAS AEDO MELANY (2).jpg
# Copiado a permanent-teeth: CARDENAS AEDO MELANY.jpg
# Copiado a permanent-teeth: CARDENAS BARRA ARACELI 14-02-05.jpg
# Copiado a permanent-teeth: CARDENAS BARRA ARACELI.jpg
# Copiado a permanent-teeth: CARDENAS CABRERA MAYENDA (2).jpg
# Copiado a milk-teeth: CARDENAS CABRERA MAYENDA 27-08-07.jpg
# Copiado a permanent-teeth: CARDENAS CABRERA MAYENDA.jpg
# Copiado a permanent-teeth: CARDENAS MILA ALFONSO (1).jpg
# Copiado a milk-teeth: CARDENAS NUÑEZ DANIEL.jpg
# Copiado a milk-teeth: CARDENAS NUÑEZ DANIEL_1.jpg
# Copiado a permanent-teeth: CARDENAS OLIVERO ARIANNA.jpg
# Copiado a milk-teeth: CARDENAS OPAZO FRANCISCA  (1).jpg
# Copiado a permanent-teeth: CAREAGA BIZARRO ERICK 24-11-06 (1).jpg
# Copiado a permanent-teeth: CAREAGA BIZARRO ERICK.jpg
# Copiado a permanent-teeth: CAREAGA BIZARRO ERICK_1.jpg
# Copiado a permanent-teeth: CARES CELEDON JOSEFINA 29-11-04.jpg
# Copiado a permanent-teeth: CARES GARRIDO PATRICIO.jpg
# Copiado a permanent-teeth: CARES GARRIDO PATRICIO_1.jpg
# Copiado a permanent-teeth: CARILAO CARILAO ELIAS.jpg
# Copiado a permanent-teeth: CARILAO MILLALEN BRYAN.jpg
# Copiado a permanent-teeth: CARILAO MILLALEN BRYAN_1.jpg
# Copiado a permanent-teeth: CARILAO MILLALEN BRYAN_2.jpg
# Copiado a permanent-teeth: CARINAO MATAMALA BENJAMIN.jpg
# Copiado a permanent-teeth: CARIPAN CAOLIPI CARLA 29-01-04.jpg
# Copiado a permanent-teeth: CARIPAN CARLA.jpg
# Copiado a permanent-teeth: CARIPAN COLIPI CARLA (2).jpg
# Copiado a permanent-teeth: CARIPAN COLIPI CARLA (2)_1.jpg
# Copiado a permanent-teeth: CARIPAN COLIPI CARLA 2.jpg
# Copiado a permanent-teeth: CARIQUEO LLANCAQUEO YULIANA  (1).jpg
# Copiado a permanent-teeth: CARIQUEO LLANCAQUEO YULIANA  (1)_1.jpg
# Copiado a milk-teeth: CARJAVAL GUTIERREZ JAVIER (1).jpg
# Copiado a permanent-teeth: CARMONA MALDONADO_R_19750415_76668912_1.jpg
# Copiado a permanent-teeth: CARMONA MALDONADO_R_19750415_76685752_1.jpg
# Copiado a permanent-teeth: CARRASCO ANTILEN KRISHNA 09-04-01.jpg
# Copiado a permanent-teeth: CARRASCO CABEZAS ARACELI  (2).jpg
# Copiado a permanent-teeth: CARRASCO CANALES FERNANDA (2).jpg
# Copiado a milk-teeth: CARRASCO CANALES VALENTINA (2).jpg
# Copiado a milk-teeth: CARRASCO MALDONADO MILLARAY.jpg
# Copiado a permanent-teeth: CARRASCO MALDONADO MILLARAY_1.jpg
# Copiado a permanent-teeth: CARRASCO MONSALVE ANTONIA  (1).jpg
# Copiado a permanent-teeth: CARRASCO MONSALVE ANTONIA  (1)_1.jpg
# Copiado a permanent-teeth: CARRASCO MONSALVE ANTONIA 14-04-19 (1).jpg
# Copiado a permanent-teeth: CARRASCO MUÑOZ EVELYN  10-03-21.jpg
# Copiado a permanent-teeth: CARRASCO REYES CAMILA  (1).jpg
# Copiado a permanent-teeth: CARRASCO REYES CAMILA  (1)_1.jpg
# Copiado a permanent-teeth: CARRILLO CID BARBARA (1).jpg
# Copiado a milk-teeth: CARRILLO PINCHEIRA JOAQUIN 09-01-12.jpg
# Copiado a milk-teeth: CARRILLO PINCHEIRA JOAQUIN.jpg
# Copiado a permanent-teeth: CARTE CARRILLO MAYRA 27-10-07.jpg
# Copiado a permanent-teeth: CARTER CANDIA IGNACIO 09-01-02 (1).jpg
# Copiado a permanent-teeth: CARTER ORTIZ JEREMY (1).jpg
# Copiado a milk-teeth: CARTER ORTIZ SASHA.jpg
# Copiado a permanent-teeth: CARTES CARRILLO MAYRA.jpg
# Copiado a permanent-teeth: CARTES CARRILLO MAYRA_1.jpg
# Copiado a milk-teeth: CARTES ERICES MAITE (2).jpg
# Copiado a permanent-teeth: CARTES MENDOZA BASTIAN (1).jpg
# Copiado a permanent-teeth: CARTES MENDOZA BASTIAN.jpg
# Copiado a permanent-teeth: CARTES MENDOZA BASTIAN_1.jpg
# Copiado a permanent-teeth: CARTES PLACENCIA SCARLET.jpg
# Copiado a permanent-teeth: CARTES PLACENCIA SCARLET_1.jpg
# Copiado a permanent-teeth: CARTES PLACENCIO SCARLET (18-04-19).jpg
# Copiado a permanent-teeth: CARTES PLACENCIO SCARLET.jpg
# Copiado a permanent-teeth: CASTILLO ALTAMIRANO MARIA ISABEL (2).jpg
# Copiado a permanent-teeth: CASTILLO ALTAMIRANO MARIA ISABEL 18-08-20.jpg
# Copiado a permanent-teeth: CASTILLO BEROIZ MATIAS.jpg
# Copiado a milk-teeth: CASTILLO CERDA ARLETH 30-06-08.jpg
# Copiado a milk-teeth: CASTILLO CERDA ARLETH.jpg
# Copiado a milk-teeth: CASTILLO CERDA ARLETH_1.jpg
# Copiado a milk-teeth: CASTILLO CERDA MAITE  (2).jpg
# Copiado a permanent-teeth: CASTILLO HERRERA MARTINA.jpg
# Copiado a milk-teeth: CASTILLO LARA LEONORA P.jpg
# Copiado a milk-teeth: CASTILLO LARA LEONORA.jpg
# Copiado a milk-teeth: CASTILLO LARA LEONORA_1.jpg
# Copiado a milk-teeth: CASTILLO LARA LEONORA_2.jpg
# Copiado a permanent-teeth: CASTILLO LARA REINALDO 07-11-2004 (1).jpg
# Copiado a permanent-teeth: CASTILLO LARA REINALDO 07-11-2004 (2).jpg
# Copiado a permanent-teeth: CASTILLO LARA REINALDO.jpg
# Copiado a milk-teeth: CASTILLO LAZCANO JOSEFA  (2).jpg
# Copiado a milk-teeth: CASTILLO LAZCANO JOSEFA  (2)_1.jpg
# Copiado a milk-teeth: CASTILLO PAINEN JAZMIN (1).jpg
# Copiado a permanent-teeth: CASTILLO ZAGAL CATALINA.jpg
# Copiado a permanent-teeth: CASTILLO ZAGAL IGNACIO.jpg
# Copiado a permanent-teeth: CASTRO ALBINO MATIAS.jpg
# Copiado a permanent-teeth: CASTRO ALBINO MATÍAS 17-02-07.jpg
# Copiado a permanent-teeth: CASTRO ALVEAL JARITZA.jpg
# Copiado a permanent-teeth: CASTRO ALVEAL JARITZA_1.jpg
# Copiado a permanent-teeth: CASTRO ALVEAL YARITZA 09-07-06 (2).jpg
# Copiado a permanent-teeth: CASTRO ALVEALJARITZA.jpg
# Copiado a permanent-teeth: CASTRO ALVEAR JARITZA.jpg
# Copiado a permanent-teeth: CASTRO CARTES DANNY.jpg
# Copiado a permanent-teeth: CASTRO CARTES DANNY_1.jpg
# Copiado a permanent-teeth: CASTRO CARTES DANNY_2.jpg
# Copiado a permanent-teeth: CASTRO CARTES DANY (2).jpg
# Copiado a permanent-teeth: CASTRO CARTES YAZMIN  (2).jpg
# Copiado a permanent-teeth: CASTRO CARTES YAZMIN  (2)_1.jpg
# Copiado a permanent-teeth: CASTRO CATALAN JOAQUIN  (2).jpg
# Copiado a milk-teeth: CASTRO COLIHUIL SOFIA  (2).jpg
# Copiado a milk-teeth: CASTRO COLIHUIL SOFIA  (2)_1.jpg
# Copiado a milk-teeth: CASTRO COLIHUIL SOFIA (2).jpg
# Copiado a permanent-teeth: CASTRO FRIDERICKSEN KEISI 09-10-06 (1).jpg
# Copiado a permanent-teeth: CASTRO FRIDERICKSEN KEISI.jpg
# Copiado a permanent-teeth: CASTRO FRIDERICKSEN KEISI_1.jpg
# Copiado a milk-teeth: CASTRO HERRERA AGUSTIN  (2).jpg
# Copiado a milk-teeth: CASTRO HERRERA AGUSTIN  (2)_1.jpg
# Copiado a permanent-teeth: CASTRO OLIVA MADELAINE  (2).jpg
# Copiado a permanent-teeth: CASTRO OLIVA NICOLAS (1).jpg
# Copiado a permanent-teeth: CASTRO OLIVA NICOLAS (1)_1.jpg
# Copiado a permanent-teeth: CASTRO OLIVA NICOLAS.jpg
# Copiado a permanent-teeth: CASTRO OLIVA NICOLAS_1.jpg
# Copiado a permanent-teeth: CASTRO OLIVA NICOLAS_2.jpg
# Copiado a permanent-teeth: CASTRO PASMIÑO ALVARO 24-10-05 (2).jpg
# Copiado a permanent-teeth: CASTRO PILQUIMAN LISSETTE.jpg
# Copiado a permanent-teeth: CASTRO PILQUIMAN LUCIANA (2).jpg
# Copiado a milk-teeth: CASTRO PILQUIMAN LUCIANA 20-01-11.jpg
# Copiado a permanent-teeth: CASTRO PILQUIMAN LUCIANA.jpg
# Copiado a permanent-teeth: CASTRO POBLETE PABLA.jpg
# Copiado a permanent-teeth: CASTRO RIVAS EMILIA.jpg
# Copiado a milk-teeth: CASTRO SAN MARTIN SOFIA (2).jpg
# Copiado a permanent-teeth: CASTRO SAN MARTIN SOFIA.jpg
# Copiado a permanent-teeth: CASTRO TORO DAISY  (1).jpg
# Copiado a permanent-teeth: CASTRO TORO DAISY  (1)_1.jpg
# Copiado a permanent-teeth: CASTRO VELASQUEZ JOSUE.jpg
# Copiado a permanent-teeth: CASTRO VERDUGO CATALINA (1).jpg
# Copiado a permanent-teeth: CATALAN CIFUENTES ANTONIA (2).jpg
# Copiado a milk-teeth: CATALAN MORENO THOMAS (1).jpg
# Copiado a milk-teeth: CATALAN MORENO THOMAS (1)_1.jpg
# Copiado a permanent-teeth: CATALAN RIQUELME FERNANDA  (2).jpg
# Copiado a permanent-teeth: CATALAN RIQUELME VICENTE 20-009-05 (1).jpg
# Copiado a permanent-teeth: CATALAN RIQUELME VICENTE.jpg
# Copiado a permanent-teeth: CATALAN RIVAS SEBASTIAN  (2).jpg
# Copiado a permanent-teeth: CATALAN RIVAS SEBASTIAN  (2)_1.jpg
# Copiado a permanent-teeth: CATRICHEO HUENULLAN DIEGO.jpg
# Copiado a permanent-teeth: CATRICURA HUECHE  JAVIERA.jpg
# Copiado a permanent-teeth: CATRICURA HUENTE ALVARO.jpg
# Copiado a permanent-teeth: CATRICURA HUENTE ALVARO_1.jpg
# Copiado a permanent-teeth: CATRIHUAL MANQUE CASANDRA.jpg
# Copiado a permanent-teeth: CATRILAF FERNANDEZ DANIELA.jpg
# Copiado a permanent-teeth: CATRILAF FERNANDEZ DANIELA_1.jpg
# Copiado a milk-teeth: CATRILAF PAREDES JUAN JOSE.jpg
# Copiado a milk-teeth: CATRILAF PAREDES JUAN JOSE_1.jpg
# Copiado a permanent-teeth: CATRILAF PAREDES PATRICIA.jpg
# Copiado a permanent-teeth: CAYUAN CALABRANO SAMIRA.jpg
# Copiado a permanent-teeth: CAYUAN CHAPARRO SOFIA (1).jpg
# Copiado a permanent-teeth: CAYUL BLANCO ALEX.jpg
# Copiado a milk-teeth: CAYUL BLANCO ALEX24-11-10 (2).jpg
# Copiado a permanent-teeth: CAYUL BLANCO ALEX_1.jpg
# Copiado a permanent-teeth: CAYUL CAYUL ROSA 24-09-20.jpg
# Copiado a permanent-teeth: CAYUL CAYUL ROSA.jpg
# Copiado a permanent-teeth: CAYUL GODOY NOEMI.jpg
# Copiado a permanent-teeth: CAYUL GODOY NOEMÍ 14-01-04.jpg
# Copiado a milk-teeth: CAYUL PEREZ CRISTIAN 26-02-06 (1).jpg
# Copiado a permanent-teeth: CAYUL PEREZ CRISTIAN.jpg
# Copiado a permanent-teeth: CAYUL PEREZ CRISTIAN_1.jpg
# Copiado a permanent-teeth: CAYUL PEREZ CRISTIAN_2.jpg
# Copiado a permanent-teeth: CAYUL PEREZ CRISTIAN_3.jpg
# Copiado a permanent-teeth: CAYULEO COLIHUINCA MATIAS.jpg
# Copiado a permanent-teeth: CAYULEO LEFIMIL YONATHAN 18-08-02.jpg
# Copiado a permanent-teeth: CAYUMAN FAUNDEZ ANA MARIA  (1).jpg
# Copiado a permanent-teeth: CAYUMAN FAUNDEZ ANA MARIA  (1)_1.jpg
# Copiado a permanent-teeth: CAYUMAN GONZALEZ JOSE 27-01-04.jpg
# Copiado a permanent-teeth: CAYUMAN GONZALEZ JOSE.jpg
# Copiado a permanent-teeth: CAYUMAN GONZALEZ KATHERINE (1).jpg
# Copiado a permanent-teeth: CAYUMAN GONZALEZ KATHERINE (1)_1.jpg
# Copiado a permanent-teeth: CAYUMAN HUAIQUIÑIR ANDRES.jpg
# Copiado a permanent-teeth: CAYUMAN QUIÑEHUAL PIA.jpg
# Copiado a permanent-teeth: CAYUPAN SANDOVAL FRANCISCA.jpg
# Copiado a permanent-teeth: CAYUPI PILQUIMAN GENESIS (2).jpg
# Copiado a permanent-teeth: CAYUQUEO PAILLAL PAULINA.jpg
# Copiado a permanent-teeth: CAÑEZ CARRASCO JENNIFER.jpg
# Copiado a permanent-teeth: CAÑIUMIR PINCHEIRA DAMIAN 21-11-04 (2).jpg
# Copiado a permanent-teeth: CAÑIUNIR PINCHEIRA DAMIAN.jpg
# Copiado a permanent-teeth: CAÑUMIR PINCHEIRA DAMIAN.jpg
# Copiado a permanent-teeth: CEA ESCOBAR CATALINA 10-08-99.jpg
# Copiado a permanent-teeth: CEA MEDINA LEONARDO (2).jpg
# Copiado a permanent-teeth: CEA MEDINA LEONARDO.jpg
# Copiado a permanent-teeth: CEA MOLINA LEONARDO  (1).jpg
# Copiado a permanent-teeth: CEA MOLINA LEONARDO  (1)_1.jpg
# Copiado a milk-teeth: CEA MOLINA LEONARDO  (2).jpg
# Copiado a milk-teeth: CEA MOLINA LEONARDO  (2)_1.jpg
# Copiado a permanent-teeth: CEA TORRES BASTIAN.jpg
# Copiado a milk-teeth: CEAS TORRES BASTIAN.jpg
# Copiado a permanent-teeth: CELEDON ARAVENA BENJAMIN.jpg
# Copiado a permanent-teeth: CELEDON ARAVENA FRANCISCA 05-03-03 (2).jpg
# Copiado a milk-teeth: CELEDON LLANQUIMAN EMILY  (1).jpg
# Copiado a milk-teeth: CELEDON LLANQUIMAN EMILY  (1)_1.jpg
# Copiado a milk-teeth: CELEDON LLANQUIMIN EMILY.jpg
# Copiado a permanent-teeth: CELIS LOPEZ IÑIACKY  (1).jpg
# Copiado a permanent-teeth: CELIS LOPEZ IÑIACKY  (1)_1.jpg
# Copiado a permanent-teeth: CELIS LOPEZ IÑIACKY.jpg
# Copiado a permanent-teeth: CELIS LOPEZ VICTORIA.jpg
# Copiado a permanent-teeth: CELIS VARGAS FERNANDA 12-07-05.jpg
# Copiado a permanent-teeth: CELIS VARGAS FERNANDA.jpg
# Copiado a permanent-teeth: CERDA CRUCES VALENTINA 20-04-07 (1).jpg
# Copiado a permanent-teeth: CERDA LILLO CONSTANZA 15-03-07 (1).jpg
# Copiado a permanent-teeth: CERDA MARTINEZ DENISSE 10-03-02.jpg
# Copiado a permanent-teeth: CERDA MARTIONEZ DENISSE.jpg
# Copiado a permanent-teeth: CERDA MELLADO JAVIERA (2).jpg
# Copiado a permanent-teeth: CERDA MELLADO JAVIERA.jpg
# Copiado a permanent-teeth: CERDA MELLADO JAVIERA_1.jpg
# Copiado a milk-teeth: CERDA MELLADO LAURA (2).jpg
# Copiado a milk-teeth: CERDA MELLADO LAURA.jpg
# Copiado a milk-teeth: CERDA MELLADO LAURA_1.jpg
# Copiado a milk-teeth: CERDA NUÑEZ CRISTOBAL 17-04-2008 (2).jpg
# Copiado a permanent-teeth: CERDA NUÑEZ CRISTOBAL.jpg
# Copiado a permanent-teeth: CERDA NUÑEZ CRISTOBAL_1.jpg
# Copiado a permanent-teeth: CERDA NUÑEZ CRISTOBAL_2.jpg
# Copiado a permanent-teeth: CERDA NUÑEZ CRISTOBAL_3.jpg
# Copiado a permanent-teeth: CERDA SAEZ PASCUALA  (2).jpg
# Copiado a permanent-teeth: CESPEDES ORIA BENJAMIN.jpg
# Copiado a permanent-teeth: CESPEDES ORIAS BENJAMIN.jpg
# Copiado a permanent-teeth: CESPEDES ORIO BENJAMIN.jpg
# Copiado a milk-teeth: CHAHUD VIGUERA VALENTINA.jpg
# Copiado a milk-teeth: CHAHUD VIGUERA VALENTINA_1.jpg
# Copiado a permanent-teeth: CHANDIA CALFANTE BENJAMIN (2).jpg
# Copiado a permanent-teeth: CHANDIA COÑA NATALY.jpg
# Copiado a permanent-teeth: CHANDIA COÑA RICHARD.jpg
# Copiado a permanent-teeth: CHANDIA COÑA RICHARD_1.jpg
# Copiado a permanent-teeth: CHANDIA COÑA RICHARD_2.jpg
# Copiado a permanent-teeth: CHANDIA PERALTA JUAN.jpg
# Copiado a permanent-teeth: CHANQUEO MANRIQUE NATASHA.jpg
# Copiado a permanent-teeth: CHANQUEO MANRIQUEZ NATASHA (2).jpg
# Copiado a permanent-teeth: CHANQUEO MANRIQUEZ NATASHA 2.jpg
# Copiado a permanent-teeth: CHANQUEO MANRIQUEZ NATASHA.jpg
# Copiado a permanent-teeth: CHANQUEO MANRIQUEZ NATASHA_1.jpg
# Copiado a permanent-teeth: CHAUCON PIRUL CARLA.jpg
# Copiado a permanent-teeth: CHAVEZ NAVARRETE CATALINA  (2).jpg
# Copiado a permanent-teeth: CHAVEZ NAVARRETE CATALINA  (2)_1.jpg
# Copiado a milk-teeth: CHAVEZ NAVARRETE MARTINA 20-08-10.jpg
# Copiado a permanent-teeth: CHAVEZ NAVARRETE MARTINA.jpg
# Copiado a permanent-teeth: CHAVEZ NAVARRETE MARTINA_1.jpg
# Copiado a permanent-teeth: CHAVEZ NAVARRETE MARTINA_2.jpg
# Copiado a permanent-teeth: CHAVEZ NAVARRETE MARTINA_3.jpg
# Copiado a permanent-teeth: CHAVEZ NAVARRETE MARTINA_4.jpg
# Copiado a milk-teeth: CHAVEZ QUEZADA MONSERRAT.jpg
# Copiado a permanent-teeth: CHAVEZ QUEZADA MONSERRAT_1.jpg
# Copiado a milk-teeth: CHAVEZ SANJUAN REINALDO.jpg
# Copiado a permanent-teeth: CHEHUAN VIDAL CAROLINA 28-08-06.jpg
# Copiado a permanent-teeth: CHEQUEPAN COLICHEO CAROLA (2).jpg
# Copiado a milk-teeth: CHEUQUENAO AEDO DAYRIS (2).jpg
# Copiado a permanent-teeth: CHEUQUENAO SANHUEZA KATHERINA.jpg
# Copiado a permanent-teeth: CHEUQUEPAN  COLICHEO CAROLA.jpg
# Copiado a permanent-teeth: CHEUQUEPAN CIFUENTES MILLARAY 27-11-07 (1).jpg
# Copiado a permanent-teeth: CHEUQUEPAN CIFUENTES MILLARAY.jpg
# Copiado a permanent-teeth: CHIHUAICURA CANIO RICARDO.jpg
# Copiado a permanent-teeth: CHIHUAICURA CANIO RICARDO_1.jpg
# Copiado a milk-teeth: CHIHUAICURA CANIO RICARDO_2.jpg
# Copiado a milk-teeth: CHIHUICURA CANIO RICARDO.jpg
# Copiado a milk-teeth: CHIHUICURA CANIO RICARDO_1.jpg
# Copiado a permanent-teeth: CHUÑIL SAN MARTIN MATIAS.jpg
# Copiado a permanent-teeth: CHUÑIL SAN MARTIN MATIAS_1.jpg
# Copiado a milk-teeth: CHUÑIL SAN MARTIN MATÍAS 27-09-2007 (2).jpg
# Copiado a milk-teeth: CHUÑIL SAN MARTIN TRINIDAD (2).jpg
# Copiado a milk-teeth: CHUÑIL SAN MARTIN TRINIDAD 12-02-11 (1).jpg
# Copiado a permanent-teeth: CHUÑIL SAN MARTIN TRINIDAD.jpg
# Copiado a milk-teeth: CHUÑIL SAN MARTIN TRINIDAD_1.jpg
# Copiado a permanent-teeth: CHUÑIL SAN MARTIN TRINIDAD_2.jpg
# Copiado a permanent-teeth: CID CID CONSTANZA.jpg
# Copiado a permanent-teeth: CID CID CONSTANZA_1.jpg
# Copiado a permanent-teeth: CID ESPINOZA VALERIA (2).jpg
# Copiado a permanent-teeth: CID ESPINOZA VALERIA (2)_1.jpg
# Copiado a permanent-teeth: CID ESPINOZA VALERIA.jpg
# Copiado a milk-teeth: CID MARTINEZ CONSTANZA 07-11-03.jpg
# Copiado a milk-teeth: CID MARTINEZ CONSTANZA 2.jpg
# Copiado a milk-teeth: CID MARTINEZ CONSTANZA 3.jpg
# Copiado a permanent-teeth: CID MARTINEZ CONSTANZA.jpg
# Copiado a permanent-teeth: CID MARTINEZ CONSTANZA_1.jpg
# Copiado a permanent-teeth: CID MARTINEZ CONSTANZA_2.jpg
# Copiado a permanent-teeth: CID MARTINEZ COSTANZA 2.jpg
# Copiado a permanent-teeth: CID ORTIZ AARON.jpg
# Copiado a permanent-teeth: CID ORTIZ AARON_1.jpg
# Copiado a permanent-teeth: CID ORTIZ AARON_2.jpg
# Copiado a permanent-teeth: CID ORTIZ AARON_3.jpg
# Copiado a milk-teeth: CID PAZ KRISHNA  19-12-99.jpg
# Copiado a permanent-teeth: CID VASQUEZ JENNIFER (2).jpg
# ...
# Copiado a milk-teeth: TORRES BARRIGA LYSSETE.jpg
# Copiado a milk-teeth: TORRES CALAPAY NEZARET 01-09-07 (1).jpg
# Copiado a permanent-teeth: TORRES COLLINAO QUIDEL 09-04-05.jpg
# Copiado a permanent-teeth: TORRES MANQUILEF JAZMIN  04-03-16 (2).jpg
# Copiado a permanent-teeth: TORRES MERILLAN AGUSTIN.jpg
# Copiado a permanent-teeth: TORRES MUÑOZ MARTINA 17-09-06 (2).jpg
# Copiado a permanent-teeth: TORRES OLATE RICARDO  (2).jpg
# Copiado a permanent-teeth: TORRES OLATE RICARDO  (2)_1.jpg
# Copiado a permanent-teeth: TORRES OLIVA KATHERINE 27-01-04.jpg
# Copiado a permanent-teeth: TORRES PAINEFIL PAMELA.jpg
# Copiado a milk-teeth: TORRES PONCE SOFIA  (2).jpg
# Copiado a milk-teeth: TORRES PONCE SOFIA  (2)_1.jpg
# Copiado a milk-teeth: TORRES PONCE SOFIA  (2)_2.jpg
# Copiado a permanent-teeth: TORRES SOTO ANTONIA  (2).jpg
# Copiado a permanent-teeth: TORRES SOTO ANTONIA  (2)_1.jpg
# Copiado a permanent-teeth: TRAIPE CAMPOS CATALINA  (2).jpg
# Copiado a permanent-teeth: TRAIPE CAMPOS CATALINA  (2)_1.jpg
# Copiado a permanent-teeth: TRAIPE SALAMANCA BENJAMIN  (1).jpg
# Copiado a permanent-teeth: TRAIPI CALFIL LUCAS.jpg
# Copiado a permanent-teeth: TRALCAL GARCIA ANTONIO  (2).jpg
# Copiado a permanent-teeth: TRALCAL GARCIA ANTONIO  (2)_1.jpg
# Copiado a permanent-teeth: TRALCAL GARCIA ANTONIO  (2)_2.jpg
# Copiado a permanent-teeth: TRALCAL TRALCAL IVETTE (2).jpg
# Copiado a permanent-teeth: TRALCAL TRALCAL IVETTE 20-09-04 (1).jpg
# Copiado a permanent-teeth: TRANAMIL COLIL LUZ.jpg
# Copiado a permanent-teeth: TRANAMIL COLIN LUZ 26-10-02.jpg
# Copiado a permanent-teeth: TRECAMAN COLLIO GISSELLE.jpg
# Copiado a milk-teeth: TRECANAO ESCOBEDO SARA 10-05-2011 (1).jpg
# Copiado a permanent-teeth: TREUPIL RAIN JENIFER.jpg
# Copiado a permanent-teeth: TREUPIL RAIN JENNIFER 20-02-06 (2).jpg
# Copiado a permanent-teeth: TRIGO CALFIU ELENA   19-05-21.jpg
# Copiado a permanent-teeth: TRIGO CALFIU ELENA.jpg
# Copiado a permanent-teeth: TRIGO CALFIU ELENA_1.jpg
# Copiado a milk-teeth: TRIPAÑAN SAN MARTIN SABINA  (2).jpg
# Copiado a milk-teeth: TRIPAÑAN SAN MARTIN SABINA  (2)_1.jpg
# Copiado a milk-teeth: TRONCOSO CAMPOS ANAIS 27-07-04.jpg
# Copiado a permanent-teeth: TRONCOSO CAMPOS ANAIS 30-09-21.jpg
# Copiado a permanent-teeth: TRONCOSO CURIFIL IGNACIO.jpg
# Copiado a permanent-teeth: TROPAN TROPAN BASTIAN.jpg
# Copiado a permanent-teeth: TRUDEO SICAN YAILER 02-04-02.jpg
# Copiado a milk-teeth: TURRA COÑA SOFIA.jpg
# Copiado a milk-teeth: TURRA COÑA SOFIA_1.jpg
# Copiado a milk-teeth: TURRA COÑA SOFIA_2.jpg
# Copiado a permanent-teeth: TURRA ROCHA ESTEBAN.jpg
# Copiado a permanent-teeth: TURRA ROCHA_ ESTEBAN.jpg
# Copiado a permanent-teeth: ULLOA GUZMAN KEVIN  (2).jpg
# Copiado a permanent-teeth: ULLOA GUZMAN KEVIN  (2)_1.jpg
# Copiado a permanent-teeth: ULLOA GUZMAN KEVIN 12-01-03.jpg
# Copiado a permanent-teeth: ULLOA VALDIVIESO DAYANE 09-01-02.jpg
# Copiado a milk-teeth: UMANZOR FERNANDEZ ANTONELLA.jpg
# Copiado a milk-teeth: UMANZOR FERNANDEZ_ ANTONELLA (1).jpg
# Copiado a permanent-teeth: URIBE CARRASCO DANIELA.jpg
# Copiado a permanent-teeth: URIBE SANHUEZA FRANCISCA.jpg
# Copiado a permanent-teeth: URRA HUAIQUIO JASON 24-09-20.jpg
# Copiado a permanent-teeth: URRA HUAIQUIO TAMARA 24-09-20.jpg
# Copiado a milk-teeth: URRA MELINAO FELIPE  (2).jpg
# Copiado a permanent-teeth: URRUTIA PEREZ ALINA (1).jpg
# Copiado a permanent-teeth: URRUTIA PEREZ ALINA.jpg
# Copiado a permanent-teeth: URRUTIA PEREZ ALINA_1.jpg
# Copiado a permanent-teeth: VAELNZUELA ARRIAGADA CRISTOPHER 04-05-03.jpg
# Copiado a permanent-teeth: VALDEBENITO LIEMPI MARCELA 14-07-06 (2).jpg
# Copiado a permanent-teeth: VALDERRAMA VALDERRAMA FLORENCIA (2).jpg
# Copiado a permanent-teeth: VALDERRAMA VALDERRAMA FLORENCIA.jpg
# Copiado a permanent-teeth: VALDES CAMPOS JONATHAN.jpg
# Copiado a permanent-teeth: VALDES CAMPOS JONATHAN_1.jpg
# Copiado a milk-teeth: VALDES HUENUMAN IGNACIA.jpg
# Copiado a permanent-teeth: VALDES HUENUMAN MATIAS (2).jpg
# Copiado a permanent-teeth: VALDEZ FIGUEROA ISAIAS 19-03-2006 (1).jpg
# Copiado a permanent-teeth: VALDIVIA BARRALES FERNANDA 02-12-00.jpg
# Copiado a permanent-teeth: VALENZUELA  MARTINEZ SOFIA  (1).jpg
# Copiado a permanent-teeth: VALENZUELA ARRIAGADA CRISTOPHER.jpg
# Copiado a permanent-teeth: VALENZUELA ARRIAGADA CRISTOPHER_1.jpg
# Copiado a permanent-teeth: VALENZUELA ARRIAGADA SOFIA.jpg
# Copiado a permanent-teeth: VALENZUELA CAULLAN ALONSO.jpg
# Copiado a milk-teeth: VALENZUELA HERNANDEZ ARACELLY.jpg
# Copiado a permanent-teeth: VALENZUELA HUENULAO PASCAL.jpg
# Copiado a permanent-teeth: VALENZUELA INOSTROZA KEVIN  (2).jpg
# Copiado a permanent-teeth: VALENZUELA INOSTROZA KEVIN  (2)_1.jpg
# Copiado a permanent-teeth: VALENZUELA INOSTROZA KEVIN  (2)_2.jpg
# Copiado a permanent-teeth: VALENZUELA MARTINEZ SOFIA.jpg
# Copiado a permanent-teeth: VALENZUELA MESIAS YANARA  (2).jpg
# Copiado a permanent-teeth: VALENZUELA MESIAS YANARA  (2)_1.jpg
# Copiado a permanent-teeth: VALENZUELA RETAMAL  ZAMIRA.jpg
# Copiado a permanent-teeth: VALENZUELA RETAMAL ZAMIRA 14-07-03.jpg
# Copiado a permanent-teeth: VALENZUELA VELASQUEZ FERNANDO (2).jpg
# Copiado a permanent-teeth: VALLADARES SILVA DANIELA (1).jpg
# Copiado a permanent-teeth: VALLADARES SILVA DANIELA.jpg
# Copiado a permanent-teeth: VALLADARES SILVA DANIELA_1.jpg
# Copiado a permanent-teeth: VALLE VALDEBENITO CATALINA 15-07-03.jpg
# Copiado a permanent-teeth: VALLEJOS AGUAYO BRIAN  (1).jpg
# Copiado a permanent-teeth: VALLEJOS CARRASCO VICENTE  (1).jpg
# Copiado a permanent-teeth: VALLEJOS CAYULEO MARCELA.jpg
# Copiado a permanent-teeth: VALLEJOS MAYORGA GENESIS.jpg
# Copiado a permanent-teeth: VALLEJOS OBANDO CAROLINA 26-04-04 (1).jpg
# Copiado a permanent-teeth: VALLEJOS OBANDO CATALINA.jpg
# Copiado a milk-teeth: VARAS VALDEBENITO EZEQUIEL.jpg
# Copiado a milk-teeth: VARAS VALDEBENITO EZEQUIEL_1.jpg
# Copiado a milk-teeth: VARAS VALDEBENITO EZEQUIEL_2.jpg
# Copiado a permanent-teeth: VARELA HIDALGO MADELEYN  (2).jpg
# Copiado a permanent-teeth: VARGAS ARAVENA CAMILA.jpg
# Copiado a permanent-teeth: VARGAS ARAVENA CAMILA_1.jpg
# Copiado a permanent-teeth: VARGAS ARAVENA CAMILA_2.jpg
# Copiado a permanent-teeth: VARGAS ARCE JAVIERA (2).jpg
# Copiado a permanent-teeth: VARGAS ARCE JAVIERA.jpg
# Copiado a permanent-teeth: VARGAS ARCE JAVIERA_1.jpg
# Copiado a permanent-teeth: VARGAS JARAMILLO ISIDORA.jpg
# Copiado a milk-teeth: VARGAS LABRAÑA AMANDA.jpg
# Copiado a milk-teeth: VARGAS LABRAÑA AMANDA_1.jpg
# Copiado a permanent-teeth: VASQUEZ AGUILERA LETICIA (1).jpg
# Copiado a permanent-teeth: VASQUEZ AGUILERA LETICIA.jpg
# Copiado a permanent-teeth: VASQUEZ AGUILERA LETICIA_1.jpg
# Copiado a permanent-teeth: VASQUEZ AGUILERA LETICIA_2.jpg
# Copiado a milk-teeth: VASQUEZ BASTIAS DANIEL  (1).jpg
# Copiado a milk-teeth: VASQUEZ BASTIAS DANIEL  (1)_1.jpg
# Copiado a permanent-teeth: VASQUEZ DIAZ SEBASTIAN 28-07-02.jpg
# Copiado a permanent-teeth: VASQUEZ LILLO NICOLAS 15-09-02 (1).jpg
# Copiado a milk-teeth: VASQUEZ LILLO NICOLÁS 15-09-02.jpg
# Copiado a milk-teeth: VASQUEZ MANRIQUEZ MAXIMILIANO  (2).jpg
# Copiado a milk-teeth: VASQUEZ MANRIQUEZ MAXIMILIANO.jpg
# Copiado a milk-teeth: VASQUEZ MANRIQUEZ MAXIMILIANO_1.jpg
# Copiado a permanent-teeth: VASQUEZ MILLAGUIR EDUARDO 09-03-04.jpg
# Copiado a permanent-teeth: VASQUEZ MILLAGUIR FRANCISCO 02-03-06.jpg
# Copiado a permanent-teeth: VASQUEZ PAILLAN ALEJANDRA 13-09-02.jpg
# Copiado a permanent-teeth: VASQUEZ QUIJON AMYLEE 25-12-06.jpg
# Copiado a permanent-teeth: VASQUEZ QUIJON AMYLEE.jpg
# Copiado a permanent-teeth: VASQUEZ SOTO VALENTINA.jpg
# Copiado a permanent-teeth: VASQUEZ ZABATEL GINO.jpg
# Copiado a milk-teeth: VASQUEZ ZABATEL PABLO.jpg
# Copiado a permanent-teeth: VASQUEZ ZAPATEL PABLO 14-03-04.jpg
# Copiado a permanent-teeth: VASQUEZ ZUÑIGA GABRIEL  (1).jpg
# Copiado a permanent-teeth: VASQUEZ ZUÑIGA GABRIEL  (1)_1.jpg
# Copiado a permanent-teeth: VEGA ANDRADE MISELYN 03-09-20.jpg
# Copiado a permanent-teeth: VEGA ANDRADE MISELYN.jpg
# Copiado a permanent-teeth: VEGA ANDRADE MISELYN_1.jpg
# Copiado a permanent-teeth: VEGA BARRIA NATHALIE.jpg
# Copiado a permanent-teeth: VEGA FLORES ANTONELLA  (2).jpg
# Copiado a permanent-teeth: VEGA FLORES ANTONELLA  (2)_1.jpg
# Copiado a permanent-teeth: VEGA PAEZ AGUSTIN.jpg
# Copiado a milk-teeth: VEGA PAREDES CATALINA 16-10-03 (1).jpg
# Copiado a permanent-teeth: VEGA TRALMA ISIDORA.jpg
# Copiado a permanent-teeth: VEGA TRALMA ISIDORA_1.jpg
# Copiado a permanent-teeth: VEJAR AGUILERA SOFIA (1).jpg
# Copiado a milk-teeth: VEJAR CID VICTOR.jpg
# Copiado a milk-teeth: VELASQUEZ CASTRO MARTINA.jpg
# Copiado a milk-teeth: VELASQUEZ CASTRO MARTINA_1.jpg
# Copiado a milk-teeth: VELASQUEZ MORALES ANTONIO (2).jpg
# Copiado a milk-teeth: VELASQUEZ MORALES ANTONIO (2)_1.jpg
# Copiado a milk-teeth: VELIZ MARDONES KATHERINE (2).jpg
# Copiado a milk-teeth: VELIZ MARDONES KATHERINE (2)_1.jpg
# Copiado a milk-teeth: VENEGA LUENGO ISIDORA.jpg
# Copiado a milk-teeth: VENEGA LUENGO ISIDORA_1.jpg
# Copiado a permanent-teeth: VENEGAS ALVARES DIEGO.jpg
# Copiado a permanent-teeth: VENEGAS ALVAREZ DIEGO (2).jpg
# Copiado a milk-teeth: VENEGAS ARIAS JAVIERA  (1).jpg
# Copiado a milk-teeth: VENEGAS ARIAS JAVIERA  (1)_1.jpg
# Copiado a permanent-teeth: VENEGAS BURGO MARITZA.jpg
# Copiado a permanent-teeth: VENEGAS BURGOS MARITZA 02-09-03.jpg
# Copiado a permanent-teeth: VENEGAS BURGOS MARITZA.jpg
# Copiado a permanent-teeth: VENEGAS CARRASCO CONSTANZA  (1).jpg
# Copiado a permanent-teeth: VENEGAS CARRASCO MARTIN  (2).jpg
# Copiado a permanent-teeth: VENEGAS CARRASCO MARTIN  (2)_1.jpg
# Copiado a permanent-teeth: VENEGAS CARRASCO_M_20080719_342786744_1.jpg
# Copiado a permanent-teeth: VENEGAS CARRASCO_M_20080719_342786744_1_1.jpg
# Copiado a permanent-teeth: VENEGAS CURRIHUIL SOLEDAD 03-03-99 (1).jpg
# Copiado a permanent-teeth: VENEGAS CURRIHUIL SOLEDAD 03-03-99.jpg
# Copiado a permanent-teeth: VENEGAS CURRIHUIL SOLEDAD.jpg
# Copiado a permanent-teeth: VENEGAS LUENGO BIANCA.jpg
# Copiado a milk-teeth: VENEGAS LUENGO ISIDORA.jpg
# Copiado a permanent-teeth: VENEGAS LUENGO PABLO 10-07-02.jpg
# Copiado a permanent-teeth: VENEGAS TORRES ANASTASIA  (1).jpg
# Copiado a permanent-teeth: VENEGAS TORRES ANASTASIA  (1)_1.jpg
# Copiado a milk-teeth: VERA CEBALLOS JAVIERA  (2).jpg
# Copiado a milk-teeth: VERA CEBALLOS JAVIERA  (2)_1.jpg
# Copiado a permanent-teeth: VERA RIQUELME LUCAS.jpg
# Copiado a permanent-teeth: VERA RIQUELME LUCAS_1.jpg
# Copiado a milk-teeth: VERA VIVANCO SOFIA.jpg
# Copiado a permanent-teeth: VERGARA CURIN JAVIER  (1).jpg
# Copiado a permanent-teeth: VERGARA CURIN JAVIER  (1)_1.jpg
# Copiado a permanent-teeth: VERGARA JARAMILLO JOAQUIN  15-08-06 (2).jpg
# Copiado a permanent-teeth: VERGARA JELDREZ FERNANDA.jpg
# Copiado a permanent-teeth: VERGARA QUEZADA JAVIER 22-08-99.jpg
# Copiado a permanent-teeth: VIDAL FIERRO AMARO.jpg
# Copiado a permanent-teeth: VIDAL FIERRO AMAROO 22-02-06 (2).jpg
# Copiado a permanent-teeth: VIDAL RAMON DEISY.jpg
# Copiado a permanent-teeth: VIDAL RAMON MIREYA.jpg
# Copiado a permanent-teeth: VIDAL RIQUELME FLORENCIA  (2).jpg
# Copiado a permanent-teeth: VIDAL RIQUELME FLORENCIA  (2)_1.jpg
# Copiado a permanent-teeth: VIDAL RIQUELME FLORENCIA.jpg
# Copiado a permanent-teeth: VIDAL VALLEJOS JOAQUIN.jpg
# Copiado a permanent-teeth: VILLABLANCA MORA  ANSELMO.jpg
# Copiado a permanent-teeth: VILLABLANCA PRADO JOAQUIN  (1).jpg
# Copiado a permanent-teeth: VILLABLANCA PRADO JOAQUIN.jpg
# Copiado a permanent-teeth: VILLABLANCA PRADO JOAQUIN_1.jpg
# Copiado a permanent-teeth: VILLAGRA OBANDO SEBASTIAN.jpg
# Copiado a permanent-teeth: VILLAGRAN FLORES GABRIEL 02-08-06.jpg
# Copiado a permanent-teeth: VILLAGRAN FLORES GABRIEL.jpg
# Copiado a permanent-teeth: VILLAGRAN FLORES GABRIEL_1.jpg
# Copiado a permanent-teeth: VILLAGRAN HENRIQUEZ DORA.jpg
# Copiado a permanent-teeth: VILLAROEL INEIPIL JACQUELINE 26-04-05.jpg
# Copiado a permanent-teeth: VILLAROEL ROA VICENTE  (2).jpg
# Copiado a permanent-teeth: VILLAROEL ROA VICENTE  (2)_1.jpg
# Copiado a permanent-teeth: VILLARROEL INEIPIL JAQUELINE.jpg
# Copiado a permanent-teeth: VILLEGAS ULLOA NICOLAS  (1).jpg
# Copiado a milk-teeth: VILLENAS LEAL AKILES.jpg
# Copiado a permanent-teeth: VIVALLO VILLAGRAN ACELLY  (2).jpg
# Copiado a permanent-teeth: VIVANCO BALBOA TAMARA 20-06-99.jpg
# Copiado a permanent-teeth: VIVANCO BALBOA TAMARA.jpg
# Copiado a permanent-teeth: VIVAS RIVAS ASIEL  (2).jpg
# Copiado a permanent-teeth: VIVAS RIVAS ASIEL  (2)_1.jpg
# Copiado a permanent-teeth: WICKEL DIAZ_ MARJORIE 04-10-2018.jpg
# Copiado a permanent-teeth: WIEDERHOLD DEUCAMAN MAXIMILIANO.jpg
# Copiado a permanent-teeth: WIEDERHOLD DEUCAMAN MAXIMILIANO_1.jpg
# Copiado a milk-teeth: WIEDERHOLD DEUMACAN MAXIMILIANO.jpg
# Copiado a milk-teeth: WIEDERHOLD DEUMACAN MAXIMILIANO_1.jpg
# Copiado a permanent-teeth: WUSTNER FERNANDEZ KRISHNA 11-05-00.jpg
# Copiado a milk-teeth: YAGODE CASTRO ALEJANDRO.jpg
# Copiado a permanent-teeth: YAGODE CASTRO CATALINA.jpg
# Copiado a permanent-teeth: YAÑEZ ALVAREZ SELENE (2).jpg
# Copiado a permanent-teeth: YAÑEZ ALVAREZ SELENE.jpg
# Copiado a permanent-teeth: YAÑEZ ALVAREZ SELENE_1.jpg
# Copiado a permanent-teeth: YAÑEZ GUTIERREZ NICOLAS.jpg
# Copiado a permanent-teeth: YAÑEZ ITURRIETA FRANCISCO 14-02-02.jpg
# Copiado a permanent-teeth: ZAGAL SALAS CONSTANZA 12-04-06.jpg
# Copiado a permanent-teeth: ZAGAL SALAS CONSTANZA.jpg
# Copiado a permanent-teeth: ZAGAL SALAS CONSTANZA_1.jpg
# Copiado a permanent-teeth: ZAGAL SALAS LUIS 19-01-2005 (2).jpg
# Copiado a permanent-teeth: ZAMBRANBO PICHICONA  DOMINIC  (2).jpg
# Copiado a permanent-teeth: ZAMBRANO BARRA NOEMI.jpg
# Copiado a permanent-teeth: ZAMBRANO PÍCHICONA LEANDRO.jpg
# Copiado a permanent-teeth: ZAMBRANO VASQUEZ ARTURO.jpg
# Copiado a permanent-teeth: ZAMBRANO VASQUEZ SAMUEL.jpg
# Copiado a permanent-teeth: ZAMBRANO VASQUEZ SAMUEL_1.jpg
# Copiado a permanent-teeth: ZAMBRANO VASQUEZ SAMUEL_2.jpg
# Copiado a permanent-teeth: ZAMBRANO YAÑEZ DANIEL 14-06-2002 (2).jpg
# Copiado a permanent-teeth: ZAMBRANO YAÑEZ DANIEL.jpg
# Copiado a permanent-teeth: ZAMBRANO YAÑEZ DANIEL_1.jpg
# Copiado a permanent-teeth: ZAPATA LIZAMA AMBAR.jpg
# Copiado a permanent-teeth: ZAPATA LIZAMA ANTONIA.jpg
# Copiado a permanent-teeth: ZAPATA MARIQUEO ABRIL.jpg
# Copiado a permanent-teeth: ZAPATA MARIQUEO ABRIL_1.jpg
# Copiado a milk-teeth: ZAPATA PAIVE IAN (2).jpg
# Copiado a milk-teeth: ZAPATA PAIVE IAN.jpg
# Copiado a milk-teeth: ZAPATA ULLOA PAULO 27-08-04.jpg
# Copiado a permanent-teeth: ZAPATA ULLOA PAULO.jpg
# Copiado a permanent-teeth: ZARATE BERIOZA ESTRELLA.jpg
# Copiado a permanent-teeth: ZARATE BERIOZA ESTRELLA_1.jpg
# Copiado a permanent-teeth: ZARATE BEROIZA ESTRELLA (2).jpg
# Copiado a permanent-teeth: ZAVALA CARDENAS RAFAEL  (1).jpg
# Copiado a permanent-teeth: ZAVALA CARDENAS RAFAEL  (1)_1.jpg
# Copiado a permanent-teeth: ZUMELZU VERGARA SEBASTIAN 29-11-97.jpg
# Copiado a permanent-teeth: ZUÑIGA ESCOBAR JUSTIN (2).jpg
# Copiado a permanent-teeth: ZUÑIGA FONSECA ISIDORA  (1).jpg
# Copiado a permanent-teeth: ZUÑIGA FONSECA LUCIANO  (1).jpg
# Copiado a permanent-teeth: ZUÑIGA FONSECA LUCIANO  (2).jpg
# Copiado a permanent-teeth: ZUÑIGA FONSECA LUCIANO (1).jpg
# Copiado a milk-teeth: ZUÑIGA FONSECA LUCIANO (3).jpg
# Copiado a permanent-teeth: ZUÑIGA HERNANDEZ PAULA (2).jpg
# Copiado a permanent-teeth: ZUÑIGA LAGOS EXEQUIEL 28-07-03.jpg
# Copiado a permanent-teeth: ZUÑIGA SAN MARTIN VICTOR ARIEL  (1).jpg
# Copiado a permanent-teeth: ZUÑIGA SAN MARTIN VICTOR ARIEL  (1)_1.jpg
# Copiado a permanent-teeth: ZUÑIGA SAN MARTIN VICTOR ARIEL  (2).jpg
# Copiado a permanent-teeth: ZUÑIGA SAN MARTIN VICTOR ARIEL  (2)_1.jpg
# Copiado a permanent-teeth: ZUÑIGA SANMARTIN ARIEL.jpg
# Copiado a permanent-teeth: ZUÑIGA URREA LUCAS.jpg
# Copiado a permanent-teeth: ÑANCO MUÑOZ ANGEL.jpg
# Copiado a permanent-teeth: ÑANCUVIL RUMINOT BASTIAN.jpg
# Copiado a permanent-teeth: ÑANCUVIL RUMINOT BASTIAN_1.jpg
# Copiado a permanent-teeth: ÑANCUVIL RUMINOT BASTIAN_2.jpg
# Copiado a permanent-teeth: ÑANCUVIL RUMINOT SCARLETH 21-09-09 (1).jpg
# Copiado a permanent-teeth: ÑIRIPIL CARFULEN MARCOS.jpg
# Copiado a permanent-teeth: ÑIRIPIL CARFULEN MARCOS_1.jpg
# Copiado a permanent-teeth: ÑIRIPIL CARFULEN MARCOS_2.jpg
# Total panorámicas con dientes de leche: 715
# Total panorámicas con dientes permanentes: 2593
# Archivos de dientes de leche guardados en: C:\Users\Admn\Documents\rx\data\filtered\milk-teeth
# Archivos de dientes permanentes guardados en: C:\Users\Admn\Documents\rx\data\filtered\permanent-teeth

# %%
import os
import torch
import pydicom
import numpy as np
from PIL import Image
from torchvision import transforms, models
from torch import nn
from torch.utils.data import Dataset, DataLoader
import shutil

# Función para cargar imágenes (misma que ya tienes)
def load_image(path):
    ext = os.path.splitext(path)[1].lower()
    if ext == '.dcm':
        dcm = pydicom.dcmread(path)
        arr = dcm.pixel_array.astype(np.float32)
        arr = (arr - arr.min()) * (255.0 / (arr.max() - arr.min()))
        arr = np.clip(arr, 0, 255).astype(np.uint8)
        img = Image.fromarray(arr)
    else:
        img = Image.open(path).convert('L')
    return img

# Dataset para la clasificación de brackets
class BracketsDataset(Dataset):
    def __init__(self, brackets_dir, no_brackets_dir, transform=None):
        self.brackets_files = [os.path.join(brackets_dir, f) for f in os.listdir(brackets_dir)
                             if f.lower().endswith(('.jpg', '.jpeg', '.png', '.dcm'))]
        self.no_brackets_files = [os.path.join(no_brackets_dir, f) for f in os.listdir(no_brackets_dir)
                                if f.lower().endswith(('.jpg', '.jpeg', '.png', '.dcm'))]
        self.transform = transform
        self.all_files = [(f, 1) for f in self.brackets_files] + [(f, 0) for f in self.no_brackets_files]
        
    def __len__(self):
        return len(self.all_files)
    
    def __getitem__(self, idx):
        img_path, label = self.all_files[idx]
        img = load_image(img_path)
        
        if self.transform:
            img = self.transform(img)
        
        return img, torch.tensor(label, dtype=torch.float32)
    
# Modelo para detectar brackets
class BracketsDetector(nn.Module):
    def __init__(self):
        super().__init__()
        # Usar un modelo pre-entrenado más pequeño para evitar sobreajuste
        self.model = models.resnet18(pretrained=True)
        
        # Congelar la mayoría de las capas para evitar sobreajuste
        for param in list(self.model.parameters())[:-20]:  # Congelar todo excepto las últimas capas
            param.requires_grad = False
            
        # Modificar la capa final para clasificación binaria
        num_ftrs = self.model.fc.in_features
        self.model.fc = nn.Sequential(
            nn.Dropout(0.4),  # Añadir dropout para reducir sobreajuste
            nn.Linear(num_ftrs, 1),
            nn.Sigmoid()  # Para salida binaria
        )
    
    def forward(self, x):
        return self.model(x)
# Transformaciones con data augmentation
brackets_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.RandomRotation(10),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Configurar directorios
brackets_dir = r"C:\Users\Admn\Documents\rx\data\training\brackets"          # Imágenes con brackets
no_brackets_dir = r"C:\Users\Admn\Documents\rx\data\training\no-brackets"    # Imágenes sin brackets

# Preparar dataset y dataloader
dataset = BracketsDataset(brackets_dir, no_brackets_dir, transform=brackets_transform)
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

# Configuración del entrenamiento
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = BracketsDetector().to(device)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.0001)
num_epochs = 15

# Entrenamiento
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device).unsqueeze(1)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        predicted = (outputs > 0.5).float()
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    # Evaluar en conjunto de prueba
    model.eval()
    test_correct = 0
    test_total = 0
    
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device).unsqueeze(1)
            outputs = model(inputs)
            predicted = (outputs > 0.5).float()
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()
    
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(train_loader):.4f}, "
          f"Train Acc: {100*correct/total:.2f}%, Test Acc: {100*test_correct/test_total:.2f}%")

# Guardar el modelo
torch.save(model.state_dict(), 'brackets_detector.pth')

def filter_milk_teeth_without_brackets(milk_teeth_dir, no_brackets_output_dir, brackets_output_dir):
    # Cargar el modelo de detección de brackets
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    brackets_model = BracketsDetector().to(device)
    brackets_model.load_state_dict(torch.load('brackets_detector.pth', map_location=device))
    brackets_model.eval()
    
    # Transformación para evaluación 
    eval_transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.Grayscale(num_output_channels=3),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    # Crear directorio de salida si no existe
    if not os.path.exists(no_brackets_output_dir):
        os.makedirs(no_brackets_output_dir)

    if not os.path.exists(brackets_output_dir):
        os.makedirs(brackets_output_dir)
    
    # Contador para estadísticas
    total = 0
    without_brackets = 0
    
    # Procesar cada imagen
    for filename in os.listdir(milk_teeth_dir):
        if filename.lower().endswith(('.jpg', '.jpeg', '.png', '.dcm')):
            filepath = os.path.join(milk_teeth_dir, filename)
            total += 1
            
            # Cargar y preprocesar imagen
            img = load_image(filepath)
            img_tensor = eval_transform(img).unsqueeze(0).to(device)
            
            # Detectar brackets
            with torch.no_grad():
                output = brackets_model(img_tensor)
                has_brackets = output.item() > 0.5
            
            # Si no tiene brackets, copiar a la carpeta de salida
            if not has_brackets:
                without_brackets += 1
                shutil.copy2(filepath, os.path.join(no_brackets_output_dir, filename))
                print(f"Copiado: {filename} (sin brackets)")

            else:
                print(f"Copiado: {filename} (con brackets)")
                shutil.copy2(filepath, os.path.join(brackets_output_dir, filename))
    
    print(f"Procesamiento completado. {without_brackets}/{total} imágenes sin brackets.")


milk_teeth_dir = r"C:\Users\Admn\Documents\rx\data\filtered\milk-teeth"  # Carpeta con todas las imágenes de dientes de leche
no_brackets_output_dir = r"C:\Users\Admn\Documents\rx\data\filtered\milk-teeth-no-brackets"  # Carpeta para guardar imágenes sin brackets
brackets_output_dir = r"C:\Users\Admn\Documents\rx\data\filtered\milk-teeth-with-brackets"  # Carpeta para guardar imágenes con brackets
filter_milk_teeth_without_brackets(milk_teeth_dir, no_brackets_output_dir, brackets_output_dir)
# Out:
# Epoch 1/15, Loss: 0.6935, Train Acc: 61.90%, Test Acc: 62.50%
# Epoch 2/15, Loss: 0.5521, Train Acc: 71.43%, Test Acc: 75.00%
# Epoch 3/15, Loss: 0.4690, Train Acc: 82.54%, Test Acc: 75.00%
# Epoch 4/15, Loss: 0.2605, Train Acc: 92.06%, Test Acc: 75.00%
# Epoch 5/15, Loss: 0.2431, Train Acc: 90.48%, Test Acc: 87.50%
# Epoch 6/15, Loss: 0.1981, Train Acc: 93.65%, Test Acc: 87.50%
# Epoch 7/15, Loss: 0.1462, Train Acc: 96.83%, Test Acc: 75.00%
# Epoch 8/15, Loss: 0.3172, Train Acc: 92.06%, Test Acc: 93.75%
# Epoch 9/15, Loss: 0.2032, Train Acc: 93.65%, Test Acc: 93.75%
# Epoch 10/15, Loss: 0.0916, Train Acc: 98.41%, Test Acc: 87.50%
# Epoch 11/15, Loss: 0.0953, Train Acc: 96.83%, Test Acc: 87.50%
# Epoch 12/15, Loss: 0.0578, Train Acc: 100.00%, Test Acc: 87.50%
# Epoch 13/15, Loss: 0.0446, Train Acc: 100.00%, Test Acc: 87.50%
# Epoch 14/15, Loss: 0.0838, Train Acc: 98.41%, Test Acc: 81.25%
# Epoch 15/15, Loss: 0.0465, Train Acc: 100.00%, Test Acc: 81.25%
# Copiado: ABARZUA VIDAL MARTIN (2).jpg (sin brackets)
# Copiado: ACUÑA BARRA FRANCISCA  (2).jpg (sin brackets)
# Copiado: ACUÑA BARRA FRANCISCA  (2)_1.jpg (sin brackets)
# Copiado: AEDO CURIHUAL JEDAI 08-04-03.jpg (con brackets)
# Copiado: AEDO PINO EMILIA  (2).jpg (sin brackets)
# Copiado: AEDO SALINAS ELIAM (2).jpg (con brackets)
# Copiado: AEDO SALINAS ELIAM (2)_1.jpg (con brackets)
# Copiado: AEDO SALINAS ELIAM.jpg (con brackets)
# Copiado: AGUILERA OBREQUE ANTONELLA.jpg (con brackets)
# Copiado: AGUILERA OBREQUE ANTONELLA_1.jpg (con brackets)
# Copiado: AGURTO ESPINOZA CRISTOFER.jpg (sin brackets)
# Copiado: AGURTO ESPINOZA CRISTOFER_1.jpg (sin brackets)
# Copiado: AGURTO ESPINOZA CRISTOFER_2.jpg (sin brackets)
# Copiado: ALARCON CALLUMAN CRISTIAN  (1).jpg (sin brackets)
# Copiado: ALARCON CALLUMAN CRISTIAN  (1)_1.jpg (sin brackets)
# Copiado: ALARCON DE LA FUENTE MARTIN 02-06-09  (2).jpg (sin brackets)
# Copiado: ALARCON DE LA FUENTE MARTIN PAN.jpg (sin brackets)
# Copiado: ALARCON DE LA FUENTE MARTIN.jpg (con brackets)
# Copiado: ALARCON SAEZ ANAIS  (2).jpg (con brackets)
# Copiado: ALARCON SAEZ ANAIS (2).jpg (con brackets)
# Copiado: ALVARADO ALVARADO IRIS 24-11-08.jpg (con brackets)
# Copiado: ALVAREZ HIGUIERA MARVIN  (1).jpg (sin brackets)
# Copiado: ALVAREZ HIGUIERA MARVIN  (1)_1.jpg (sin brackets)
# Copiado: ALVAREZ TORRES SOFIA  19-01-05.jpg (con brackets)
# Copiado: AMARO PACTER ROMINA 26-10-12.jpg (sin brackets)
# Copiado: ANABALON GALDAMES  MONSERRATT (1).jpg (sin brackets)
# Copiado: ANABALON GALDAMES  MONSERRATT (1)_1.jpg (sin brackets)
# Copiado: ANDANA MEDINA KEBHIN 04-10-01.jpg (con brackets)
# Copiado: ANTIMIL ROMERO FERNANDA (2).jpg (sin brackets)
# Copiado: ARANEDA CABRERA VICENTE.jpg (sin brackets)
# Copiado: ARANEDA CABRERA VICENTE_1.jpg (sin brackets)
# Copiado: ARANEDA CABRERA VICENTE_2.jpg (sin brackets)
# Copiado: ARANGO CARRASCO ESEQUIEL 03-05-10 (1).jpg (sin brackets)
# Copiado: ARIAS GUAJARDO AGUSTINA.jpg (sin brackets)
# Copiado: ARIAS REYES LAURA  (2).jpg (con brackets)
# Copiado: ARIAS REYES LAURA (2).jpg (sin brackets)
# Copiado: ARIAS REYES LAURA.jpg (con brackets)
# Copiado: ARIAS SEPULVEDA ALEXIA_1.jpg (sin brackets)
# Copiado: ARIAS SEPULVEDA ALEXIA_2.jpg (con brackets)
# Copiado: AROCA MORA CAMILA.jpg (sin brackets)
# Copiado: AROCA MORA CAMILA_1.jpg (sin brackets)
# Copiado: ARTIGAS PICUNCHE MILLARAY.jpg (con brackets)
# Copiado: ASTUDILLO ANCAMIL ENERTINA.jpg (con brackets)
# Copiado: BADILLA CASTRO CATALINA.jpg (sin brackets)
# Copiado: BARAHONA  OPAZO FRANCISCA 30-05-05.jpg (con brackets)
# Copiado: BARRAGAN BARRERA MAITE (2).jpg (sin brackets)
# Copiado: BARRAGAN BARRERA MAITE (2)_1.jpg (sin brackets)
# Copiado: BARRAGAN BARRERA MAITE.jpg (con brackets)
# Copiado: BARRAGAN BARRERA MAITE_1.jpg (con brackets)
# Copiado: BARRAGAN BARRERA MAITE_2.jpg (sin brackets)
# Copiado: BARRIA MUÑOZ AGUSTIN.jpg (sin brackets)
# Copiado: BECERRA FLORES JUVENAL_2.jpg (con brackets)
# Copiado: BECERRA FLORES JUVENAL_4.jpg (con brackets)
# Copiado: BELLO BENAVIDES  CHRISTOPHER.jpg (con brackets)
# Copiado: BELLO BENAVIDES CRISTOFER.jpg (sin brackets)
# Copiado: BELLO BENAVIDES CRISTOFER_1.jpg (sin brackets)
# Copiado: BELLO BENAVIDES CRISTOPFER.jpg (sin brackets)
# Copiado: BELLO BENAVIDES CRISTOPFER_2.jpg (con brackets)
# Copiado: BELLO BENAVIES CRISTOPHER.jpg (con brackets)
# Copiado: BELTRAN MILA BENJAMIN.jpg (sin brackets)
# Copiado: BELTRAN MILA BENJAMIN_1.jpg (sin brackets)
# Copiado: BELTRAN MILA SOFIA  (1).jpg (sin brackets)
# Copiado: BELTRAN MILA SOFIA  (1)_1.jpg (sin brackets)
# Copiado: BELTRAN ROJAS ANALIE.jpg (sin brackets)
# Copiado: BELTRAN ROJAS ANALIE_1.jpg (sin brackets)
# Copiado: BELTRAN ROJAS ANALIE_2.jpg (sin brackets)
# Copiado: BELTRAN ROJAS ANALIE_3.jpg (sin brackets)
# Copiado: BENAVIDES LIZAMA JAVIER 05-09-09 (1).jpg (sin brackets)
# Copiado: BENAVIDES LIZAMA JAVIER.jpg (con brackets)
# Copiado: BIOLLEY MUÑOZ THOMAS  (1).jpg (con brackets)
# Copiado: BIZAMA COLLIO DIANA.jpg (con brackets)
# Copiado: BIZAMA COLLIO DIANA_1.jpg (con brackets)
# Copiado: BIZAMA FIGUEROA TAMARA.jpg (con brackets)
# Copiado: BLANCK ULLOA EVOLLETTE (2).jpg (sin brackets)
# Copiado: BLANCK ULLOA EVOLLETTE.jpg (sin brackets)
# Copiado: BLUAS HIDALGO ISIDORA 10-11-09.jpg (sin brackets)
# Copiado: BOOCK MANRIQUEZ EMILIA.jpg (sin brackets)
# Copiado: BORQUEZ ALMONACID ISABELLA (2).jpg (con brackets)
# Copiado: BORQUEZ ALMONACID ISABELLA (2)_1.jpg (con brackets)
# Copiado: BRAVO PACHECO LIA  (2).jpg (sin brackets)
# Copiado: BRAVO PACHECO LIA  (2)_1.jpg (sin brackets)
# Copiado: BRICEÑO PALENCIA ABRIL.jpg (con brackets)
# Copiado: BRIONES BRAVO MAITE  (2).jpg (sin brackets)
# Copiado: BRIONES BRAVO MAITE  (2)_1.jpg (sin brackets)
# Copiado: BRIONES BRAVO PASCAL  (2).jpg (sin brackets)
# Copiado: BRIONES BRAVO PASCAL  (2)_1.jpg (sin brackets)
# Copiado: BUCHI VILLEGAS ELENA (2).jpg (sin brackets)
# Copiado: BUCHI VILLEGAS ELENA (2)_1.jpg (sin brackets)
# Copiado: BURGOS CAYUQUEO MIA  (2).jpg (con brackets)
# Copiado: BURGOS CAYUQUEO MIA  (2)_1.jpg (con brackets)
# Copiado: BURGOS JARAMILLO AMBAR  (2).jpg (con brackets)
# Copiado: BURGOS JARAMILLO AMBAR  (2)_1.jpg (con brackets)
# Copiado: BUSTAMANTE ECHEVERRIA JULIETA  (2).jpg (con brackets)
# Copiado: BUSTAMANTE ECHEVERRIA JULIETA  (2)_1.jpg (con brackets)
# Copiado: BUSTAMANTE ECHEVERRIA JULIETA  (2)_2.jpg (sin brackets)
# Copiado: BUSTOS BUSTOS MAXIMILIANO  (1).jpg (con brackets)
# Copiado: BUSTOS BUSTOS MAXIMILIANO  (1)_1.jpg (con brackets)
# Copiado: BUSTOS FARIAS VICTOR 04-07-07 (1).jpg (sin brackets)
# Copiado: BUSTOS RODRIGUEZ ISABELLA 24-11-12 (1).jpg (sin brackets)
# Copiado: BUSTOS RODRIGUEZ ISABELLA.jpg (sin brackets)
# Copiado: CABRERA GUERRERO AMANDA.jpg (con brackets)
# Copiado: CABRERA GUERRERO AMANDA_1.jpg (sin brackets)
# Copiado: CABRERA GUERRERO AMANDA_2.jpg (con brackets)
# Copiado: CABRERA GUERRERO JOSEFINA.jpg (con brackets)
# Copiado: CABRERA GUERRERO JOSEFINA_1.jpg (sin brackets)
# Copiado: CABRERA GUERRERO JOSEFINA_2.jpg (con brackets)
# Copiado: CABRERA GUERRERO JOSEFINA_3.jpg (sin brackets)
# Copiado: CABRERA MUÑOZ AMANDA.jpg (con brackets)
# Copiado: CABRERA MUÑOZ AMANDA_1.jpg (con brackets)
# Copiado: CACERES GUTIERREZ JAVIERA_1.jpg (con brackets)
# Copiado: CALFIO VILLAGRAN JUAN PABLO (2).jpg (con brackets)
# Copiado: CALFIÑIR ORELLANA MARTINA.jpg (con brackets)
# Copiado: CALFIÑIR ORELLANA MARTINA_1.jpg (con brackets)
# Copiado: CALFIÑIR ORELLANA MARTINA_2.jpg (con brackets)
# Copiado: CALISTO CARRILLO CATALINA.jpg (con brackets)
# Copiado: CAMUS GUTIERREZ GABRIEL  (1).jpg (sin brackets)
# Copiado: CANIO REYES ANTONIA.jpg (sin brackets)
# Copiado: CANIO REYES ANTONIA_1.jpg (sin brackets)
# Copiado: CANUPI BURGOS ANIBAL 06-05-19.jpg (con brackets)
# Copiado: CARCAMO DIAZ CLAUDIO.jpg (sin brackets)
# Copiado: CARCAMO DIAZ CLAUDIO_1.jpg (con brackets)
# Copiado: CARDENAS CABRERA MAYENDA 27-08-07.jpg (con brackets)
# Copiado: CARDENAS NUÑEZ DANIEL.jpg (sin brackets)
# Copiado: CARDENAS NUÑEZ DANIEL_1.jpg (sin brackets)
# Copiado: CARDENAS OPAZO FRANCISCA  (1).jpg (con brackets)
# Copiado: CARJAVAL GUTIERREZ JAVIER (1).jpg (sin brackets)
# Copiado: CARRASCO CANALES VALENTINA (2).jpg (sin brackets)
# Copiado: CARRASCO MALDONADO MILLARAY.jpg (con brackets)
# Copiado: CARRILLO PINCHEIRA JOAQUIN 09-01-12.jpg (con brackets)
# Copiado: CARRILLO PINCHEIRA JOAQUIN.jpg (con brackets)
# Copiado: CARTER ORTIZ SASHA.jpg (con brackets)
# Copiado: CARTES ERICES MAITE (2).jpg (sin brackets)
# Copiado: CASTILLO CERDA ARLETH 30-06-08.jpg (con brackets)
# Copiado: CASTILLO CERDA ARLETH.jpg (con brackets)
# Copiado: CASTILLO CERDA ARLETH_1.jpg (con brackets)
# Copiado: CASTILLO CERDA MAITE  (2).jpg (con brackets)
# Copiado: CASTILLO LARA LEONORA P.jpg (sin brackets)
# Copiado: CASTILLO LARA LEONORA.jpg (con brackets)
# Copiado: CASTILLO LARA LEONORA_1.jpg (con brackets)
# Copiado: CASTILLO LARA LEONORA_2.jpg (sin brackets)
# Copiado: CASTILLO LAZCANO JOSEFA  (2).jpg (con brackets)
# Copiado: CASTILLO LAZCANO JOSEFA  (2)_1.jpg (con brackets)
# Copiado: CASTILLO PAINEN JAZMIN (1).jpg (con brackets)
# Copiado: CASTRO COLIHUIL SOFIA  (2).jpg (con brackets)
# Copiado: CASTRO COLIHUIL SOFIA  (2)_1.jpg (con brackets)
# Copiado: CASTRO COLIHUIL SOFIA (2).jpg (sin brackets)
# Copiado: CASTRO HERRERA AGUSTIN  (2).jpg (con brackets)
# Copiado: CASTRO HERRERA AGUSTIN  (2)_1.jpg (con brackets)
# Copiado: CASTRO PILQUIMAN LUCIANA 20-01-11.jpg (sin brackets)
# Copiado: CASTRO SAN MARTIN SOFIA (2).jpg (con brackets)
# Copiado: CATALAN MORENO THOMAS (1).jpg (con brackets)
# Copiado: CATALAN MORENO THOMAS (1)_1.jpg (con brackets)
# Copiado: CATRILAF PAREDES JUAN JOSE.jpg (sin brackets)
# Copiado: CATRILAF PAREDES JUAN JOSE_1.jpg (sin brackets)
# Copiado: CAYUL BLANCO ALEX24-11-10 (2).jpg (sin brackets)
# Copiado: CAYUL PEREZ CRISTIAN 26-02-06 (1).jpg (con brackets)
# Copiado: CEA MOLINA LEONARDO  (2).jpg (con brackets)
# Copiado: CEA MOLINA LEONARDO  (2)_1.jpg (con brackets)
# Copiado: CEAS TORRES BASTIAN.jpg (sin brackets)
# Copiado: CELEDON LLANQUIMAN EMILY  (1).jpg (sin brackets)
# Copiado: CELEDON LLANQUIMAN EMILY  (1)_1.jpg (sin brackets)
# Copiado: CELEDON LLANQUIMIN EMILY.jpg (sin brackets)
# Copiado: CERDA MELLADO LAURA (2).jpg (sin brackets)
# Copiado: CERDA MELLADO LAURA.jpg (con brackets)
# Copiado: CERDA MELLADO LAURA_1.jpg (con brackets)
# Copiado: CERDA NUÑEZ CRISTOBAL 17-04-2008 (2).jpg (sin brackets)
# Copiado: CHAHUD VIGUERA VALENTINA.jpg (sin brackets)
# Copiado: CHAHUD VIGUERA VALENTINA_1.jpg (con brackets)
# Copiado: CHAVEZ NAVARRETE MARTINA 20-08-10.jpg (con brackets)
# Copiado: CHAVEZ QUEZADA MONSERRAT.jpg (con brackets)
# Copiado: CHAVEZ SANJUAN REINALDO.jpg (con brackets)
# Copiado: CHEUQUENAO AEDO DAYRIS (2).jpg (con brackets)
# Copiado: CHIHUAICURA CANIO RICARDO_2.jpg (con brackets)
# Copiado: CHIHUICURA CANIO RICARDO.jpg (con brackets)
# Copiado: CHIHUICURA CANIO RICARDO_1.jpg (con brackets)
# Copiado: CHUÑIL SAN MARTIN MATÍAS 27-09-2007 (2).jpg (sin brackets)
# Copiado: CHUÑIL SAN MARTIN TRINIDAD (2).jpg (sin brackets)
# Copiado: CHUÑIL SAN MARTIN TRINIDAD 12-02-11 (1).jpg (sin brackets)
# Copiado: CHUÑIL SAN MARTIN TRINIDAD_1.jpg (con brackets)
# Copiado: CID MARTINEZ CONSTANZA 07-11-03.jpg (con brackets)
# Copiado: CID MARTINEZ CONSTANZA 2.jpg (con brackets)
# Copiado: CID MARTINEZ CONSTANZA 3.jpg (con brackets)
# Copiado: CID PAZ KRISHNA  19-12-99.jpg (con brackets)
# Copiado: CIFUENTES MANSILLA ANTONYA  (1).jpg (con brackets)
# Copiado: COLIPI HUIRCAN LUIS (1).jpg (con brackets)
# Copiado: COLIPI HUIRCAN LUIS.jpg (con brackets)
# Copiado: COLIPI HUIRCAN LUIS_1.jpg (con brackets)
# Copiado: CONCHA ESTRADA AGUSTIN 30-07-07.jpg (con brackets)
# Copiado: CONCHA ESTRADA IGNACIO 30-07-07.jpg (con brackets)
# Copiado: CONTRERAS PONCE CRISTIAN.jpg (con brackets)
# Copiado: CONTRERAS ZAPATA VALENTINA.jpg (con brackets)
# Copiado: CORONADO DELGADO ARAY.jpg (con brackets)
# Copiado: CORREA GARRIDO GENESIS 11-09-20.jpg (con brackets)
# Copiado: CORTES SALGADO ROMINA.jpg (con brackets)
# Copiado: CORTES SALGADO ROMINA_1.jpg (con brackets)
# Copiado: CORTES SALGADO ROMINA_2.jpg (con brackets)
# Copiado: CORTES SALGADO ROMINA_3.jpg (con brackets)
# Copiado: CRAVERO ARANEDA MAITE 20-10-11 (2).jpg (sin brackets)
# Copiado: CRAVERO ARANEDA MAITE.jpg (sin brackets)
# Copiado: CRAVERO ARAVENA MAITE.jpg (sin brackets)
# Copiado: CURIN FLORES ESCARLET 19-01-02 (1).jpg (con brackets)
# Copiado: DAYNE FLORES GABRIELA.jpg (sin brackets)
# Copiado: DE LA FUENTE CADIZ MARIA PAZ.jpg (sin brackets)
# Copiado: DE LA FUENTE CADIZ MARIA PAZ_1.jpg (sin brackets)
# Copiado: DE LA FUENTE CADIZ MARIA PAZ_2.jpg (sin brackets)
# Copiado: DE LA FUENTE GARCIA SOFIA (2).jpg (con brackets)
# Copiado: DE LA FUENTE MILLANAO MAXIMILIANO  (2).jpg (sin brackets)
# Copiado: DE LA FUENTE MILLANAO MAXIMILIANO  (2)_1.jpg (sin brackets)
# Copiado: DELGADILLO LAGOS LUCAS 03-02-05 (2).jpg (con brackets)
# Copiado: DELGADILLO LAGOS LUCAS.jpg (con brackets)
# Copiado: DELGADILLO LAGOS LUCAS_1.jpg (con brackets)
# Copiado: DIAZ BASTIAS CAMILA 26-01-2007 (1).jpg (sin brackets)
# Copiado: DIAZ CONTRERAS JULIAN (2).jpg (sin brackets)
# Copiado: DIAZ CONTRERAS JULIAN.jpg (con brackets)
# Copiado: DIAZ CONTRERAS JULIAN_1.jpg (sin brackets)
# Copiado: DIAZ CONTRERAS JULIAN_2.jpg (sin brackets)
# Copiado: DIAZ GONZALEZ AGUSTIN 22-10-11 (2).jpg (sin brackets)
# Copiado: DIAZ GUTIERREZ CONSTANZA.jpg (sin brackets)
# Copiado: DIAZ MORALES AGUSTIN.jpg (sin brackets)
# Copiado: DIAZ ORELLANA JOEL 2019.jpg (sin brackets)
# Copiado: DIAZ ORELLANA JOEL 2019_1.jpg (sin brackets)
# Copiado: DIAZ TORRES GERSON.jpg (sin brackets)
# Copiado: DIAZ VARAS BENJAMIN.jpg (sin brackets)
# Copiado: DIAZ VARGAS JOSE_1.jpg (con brackets)
# Copiado: DIAZ VELASQUEZ NAYHARA.jpg (con brackets)
# Copiado: DUPRET MELGAREJO MONSERRAT.jpg (sin brackets)
# Copiado: DUPRET MELGAREJO MONSERRAT_1.jpg (con brackets)
# Copiado: DUPRET MELGAREJO MONSERRAT_2.jpg (sin brackets)
# Copiado: DUPRET MELGAREJO MONSERRAT_3.jpg (sin brackets)
# Copiado: ECHEVERRIA HUECHE JOSEFA  (2).jpg (sin brackets)
# Copiado: EPULEF ZAGAL TRINIDAD 25-06-2010 (1).jpg (sin brackets)
# Copiado: ESPARZA MORALES FRANCO (2).jpg (sin brackets)
# Copiado: ESPAÑA MARILAO MELANIE  (1).jpg (sin brackets)
# Copiado: ESPAÑA MARILAO MELANIE  (1)_1.jpg (sin brackets)
# Copiado: ESPAÑA MARILAO MELANIE  (1)_2.jpg (sin brackets)
# Copiado: ESPINOZA GAJARDO ALONSO.jpg (con brackets)
# Copiado: ESPINOZA GAJARDO ALONSO_1.jpg (con brackets)
# Copiado: ESPINOZA GAJARDO ALONSO_2.jpg (sin brackets)
# Copiado: ESPINOZA GAJARDO ALONSO_3.jpg (con brackets)
# Copiado: ESPINOZA GAJARDO ALONSO_4.jpg (con brackets)
# Copiado: ESPINOZA GAJARDO CATALINA (2).jpg (sin brackets)
# Copiado: ESPINOZA MORA AGUSTIN.jpg (con brackets)
# Copiado: ESPINOZA MORA AGUSTIN_1.jpg (con brackets)
# Copiado: ESPINOZA REPOL ALVARO_1.jpg (con brackets)
# Copiado: ESPINOZA VILLA EMILY (2).jpg (sin brackets)
# Copiado: ESPINOZA VILLA EMILY.jpg (sin brackets)
# Copiado: ESPOINOZA BUSTOS LEONARDO P.jpg (sin brackets)
# Copiado: FAUNDEZ PAINE JOSE_2.jpg (con brackets)
# Copiado: FERNANDEZ AGUILERA CAMILA.jpg (con brackets)
# Copiado: FERNANDEZ AGUILERA CAMILA_1.jpg (con brackets)
# Copiado: FERNANDEZ AGUILERA CAMILA_2.jpg (con brackets)
# Copiado: FERNANDEZ MALIQUEO PALOMA  (2).jpg (sin brackets)
# Copiado: FERNANDEZ MALIQUEO PALOMA  (2)_1.jpg (sin brackets)
# Copiado: FERNANDEZ MILLAFIL SAYEN 11-05-09.jpg (sin brackets)
# Copiado: FERNANDEZ MILLAFIL SAYEN.jpg (con brackets)
# Copiado: FERNANDEZ MILLAFIL SAYEN_2.jpg (con brackets)
# Copiado: FERNANDEZ SAN MARTIN DEMIAN 28-12-10 (1).jpg (sin brackets)
# Copiado: FERNANDEZ VENEGAS CRISTIAN  (1).jpg (sin brackets)
# Copiado: FERNANDEZ VENEGAS CRISTIAN  (1)_1.jpg (sin brackets)
# Copiado: FERNANDEZ ZURITA ANTONELLA (2).jpg (sin brackets)
# Copiado: FERRADA SANDOVAL JEHYSSEL (2).jpg (sin brackets)
# Copiado: FIGUEROA ALARCON JAVIER.jpg (sin brackets)
# Copiado: FIGUEROA ALARCON MARCELO_1.jpg (sin brackets)
# Copiado: FIGUEROA STUARDO MARTINA  (1).jpg (sin brackets)
# Copiado: FIGUEROA STUARDO MARTINA  (1)_1.jpg (sin brackets)
# Copiado: FINCHEIRA ANCAN KRISTAL.jpg (con brackets)
# Copiado: FLORES ASTETE AILYN.jpg (con brackets)
# Copiado: FLORES ASTETE AILYN_1.jpg (sin brackets)
# Copiado: FLORES ASTETE AILYN_2.jpg (con brackets)
# Copiado: FLORES ASTETE AILYN_3.jpg (sin brackets)
# Copiado: FLORES JARAMILLO ANALÑIA 29-12-06 (1).jpg (con brackets)
# Copiado: FLORES LLANCAQUEO NICOLAS (1).jpg (con brackets)
# Copiado: FLORES SAEZ_C_20031218_67639256_1.jpg (con brackets)
# Copiado: FLORES VEGA JOAQUIN.jpg (sin brackets)
# Copiado: FUENTEALBA GATICA JAVIER_1.jpg (con brackets)
# Copiado: FUENTES HERNANDEZ CATALINA.jpg (con brackets)
# Copiado: GALLARDO BARRIL BENJAMIN  (1).jpg (con brackets)
# Copiado: GALLARDO BARRIL BENJAMIN (2).jpg (sin brackets)
# Copiado: GALLARDO BARRIL BENJAMIN 12-06-11 (1).jpg (sin brackets)
# Copiado: GALLARDO GANGAS WILMA.jpg (con brackets)
# Copiado: GALLARDO SANCHEZ FERNANDO  (2).jpg (sin brackets)
# Copiado: GALLARDO SANCHEZ FERNANDO  (2)_1.jpg (sin brackets)
# Copiado: GARCIAS SEITZ AYLIN.jpg (con brackets)
# Copiado: GARCIAS SEITZ AYLYN 21-10-05 (2).jpg (con brackets)
# Copiado: GARRIDO SAEZ EMILIA  (2).jpg (sin brackets)
# Copiado: GARRIDO SANHUEZA PAZ  (2).jpg (sin brackets)
# Copiado: GARRIDO SEPULVEDA FRANCISCA  (1).jpg (sin brackets)
# Copiado: GARRIDO SEPULVEDA FRANCISCA  (2).jpg (sin brackets)
# Copiado: GARRIDO SEPULVEDA FRANCISCA  (2)_1.jpg (sin brackets)
# Copiado: GARRIDO SEPULVEDA FRANCISCA (1).jpg (con brackets)
# Copiado: GARRIDO SEPULVEDA FRANCISCA 22-10-11 (1).jpg (sin brackets)
# Copiado: GARRIDO SEPULVEDA FRANCISCA_1.jpg (con brackets)
# Copiado: GARRIDO VILLAGRAN DIEGO.jpg (sin brackets)
# Copiado: GODOY QUIROZ GONZALO.jpg (sin brackets)
# Copiado: GODOY TOLOZA VALENTINA  (1).jpg (sin brackets)
# Copiado: GODOY TOLOZA VALENTINA  (1)_1.jpg (sin brackets)
# Copiado: GOMEZ ALVAREZ EMILIO  (1).jpg (con brackets)
# Copiado: GOMEZ ALVAREZ EMILIO  (1)_1.jpg (con brackets)
# Copiado: GOMEZ FUENTEALBA CONSUELO  (1).jpg (con brackets)
# Copiado: GONZALEZ ABARZUA VALENTINA  (1).jpg (sin brackets)
# Copiado: GONZALEZ ABARZUA VALENTINA  (1)_1.jpg (sin brackets)
# Copiado: GONZALEZ ABARZUA VALENTINA.jpg (sin brackets)
# Copiado: GONZALEZ ABARZUA VALENTINA_1.jpg (sin brackets)
# Copiado: GONZALEZ BRIONES VICENTE.jpg (con brackets)
# Copiado: GONZALEZ GONZALEZ DYLAN  (1).jpg (con brackets)
# Copiado: GONZALEZ GONZALEZ DYLAN  (1)_1.jpg (con brackets)
# Copiado: GONZALEZ SCHELL JAVIER 09-11-04 (1).jpg (con brackets)
# Copiado: GUERRERO ORTEGA SOPHIE_2.jpg (sin brackets)
# Copiado: GUTIERREZ CASTRO VICENTE  (2).jpg (sin brackets)
# Copiado: GUTIERREZ CASTRO VICENTE  (2)_1.jpg (sin brackets)
# Copiado: GUTIERREZ LOPEZ BENJAMIN.jpg (sin brackets)
# Copiado: GUZMAN GATICA ISAAC (1).jpg (con brackets)
# Copiado: GUZMAN GATICA ISAAC (2).jpg (con brackets)
# Copiado: GUZMAN PIZARRO PASCALE (2).jpg (sin brackets)
# Copiado: GUZMAN PIZARRO PASCALE (2)_1.jpg (sin brackets)
# Copiado: GUZMAN RIFFO SOFIA 28-09-20.jpg (sin brackets)
# Copiado: HECTOR CABRERA RUIZ.jpg (sin brackets)
# Copiado: HENRIQUEZ ESTRADA ISAAC  (1).jpg (sin brackets)
# Copiado: HENRIQUEZ ESTRADA ISAAC  (1)_1.jpg (sin brackets)
# Copiado: HENRIQUEZ ESTRADA ISAAC.jpg (sin brackets)
# Copiado: HERNANDEZ COLLIPAL JOAQUIN.jpg (sin brackets)
# Copiado: HERNANDEZ COLLIPAL JOAQUIN_1.jpg (sin brackets)
# Copiado: HERRERA BARRERA AMY 21-08-11 (2).jpg (sin brackets)
# Copiado: HERRERA BARRERA AMY.jpg (con brackets)
# Copiado: HERRERA BARRERA AMY_1.jpg (sin brackets)
# Copiado: HERRERA RIVERA GABRIEL.jpg (con brackets)
# Copiado: HERRERA VALLADARES KATALINA 28-09-10 (2).jpg (sin brackets)
# Copiado: HIDALGO FERNANDEZ LAURA.jpg (con brackets)
# Copiado: HUECHE PAILLAL YANIRA  (1).jpg (sin brackets)
# Copiado: HUECHE PAILLAL YANIRA  (1)_1.jpg (sin brackets)
# Copiado: HUENCHUPAN FIGUEROA JOSEFA.jpg (sin brackets)
# Copiado: HUENQUIAO SALAZAR FRANCISCA.jpg (sin brackets)
# Copiado: HUENTECURA VITAYO CATALINA (2).jpg (con brackets)
# Copiado: HUENTEMIL ALLILEF KALFU.jpg (sin brackets)
# Copiado: HUENTEMIL ALLILEF KALFU_1.jpg (con brackets)
# Copiado: HUENTEMIL MORENO CONSTANZA (1).jpg (sin brackets)
# Copiado: HUENTEMIL MORENO GABRIEL 02-01-06 (1).jpg (con brackets)
# Copiado: HUENUMAN HUENUMAN JAVIERA.jpg (con brackets)
# Copiado: HUENUPI BELTRAN LESLYE.jpg (con brackets)
# Copiado: HUENUQUEO  NECULQUEO FLORENCIA  (1).jpg (sin brackets)
# Copiado: HUENUQUEO  NECULQUEO FLORENCIA  (1)_1.jpg (sin brackets)
# Copiado: HUICHACURA NAMUNCURA JUDITH.jpg (con brackets)
# Copiado: HUILCAN HUIRCAN MATIAS (1).jpg (sin brackets)
# Copiado: HUILCAN HUIRCAN MATIAS.jpg (sin brackets)
# Copiado: IBARRA CRUZ JOAQUIN 08-05-05.jpg (con brackets)
# Copiado: IBAÑEZ FERNANDEZ CARLOS (2).jpg (sin brackets)
# Copiado: ILABACA PEÑA AGUSTIN.jpg (sin brackets)
# Copiado: IMIO BUSTOS JUAN PABLO 07-03-06.jpg (con brackets)
# Copiado: INOSTROZA ANDRADE ELENA (2).jpg (sin brackets)
# Copiado: INOSTROZA ANDRADE ELENA (2)_1.jpg (sin brackets)
# Copiado: INOSTROZA ANDRADE FERNANDO  (1).jpg (sin brackets)
# Copiado: INOSTROZA ANDRADE FERNANDO  (1)_1.jpg (sin brackets)
# Copiado: INOSTROZA CAYUPI ANDREA_2.jpg (con brackets)
# Copiado: INOSTROZA CAYUPI ANDREA_3.jpg (con brackets)
# Copiado: ISIDORA ZUÑIGA 2.jpg (sin brackets)
# Copiado: ISRAEL PAILLA VICENTE 08-04-08 (2).jpg (sin brackets)
# Copiado: ITURRA MOYA RAFAELA (2).jpg (sin brackets)
# Copiado: JARA ALOCILLA ISIDORA (1).jpg (sin brackets)
# Copiado: JARA ALOCILLA ISIDORA.jpg (con brackets)
# Copiado: JARA DEL VALLE NATALY 12-03-94.jpg (con brackets)
# Copiado: KIEKEBUCH SALDIAS ISABELLA  (2).jpg (sin brackets)
# Copiado: KIEKEBUCH SALDIAS ISABELLA  (2)_1.jpg (sin brackets)
# Copiado: LASCANO INOSTROZA BARBARA  (2).jpg (sin brackets)
# Copiado: LASCANO INOSTROZA BARBARA  (2)_1.jpg (sin brackets)
# Copiado: LASTRA FLORES JABES  (2).jpg (con brackets)
# Copiado: LASTRA FLORES JABES.jpg (sin brackets)
# Copiado: LAUBRIE ROMERO MILEY (2).jpg (con brackets)
# Copiado: LEAL DELGADILLO MARTIN  (1).jpg (sin brackets)
# Copiado: LEAL DELGADILLO MARTIN.jpg (con brackets)
# Copiado: LEAL LAGOS CONSTANZA  (2).jpg (sin brackets)
# Copiado: LEAL LAGOS CONSTANZA 15-12-08 (2).jpg (con brackets)
# Copiado: LEAL LAGOS EMILY.jpg (sin brackets)
# Copiado: LEAL PIZARRO VICENTE  (1).jpg (sin brackets)
# Copiado: LEIVA HUALME ROCIO (1).jpg (sin brackets)
# Copiado: LEIVA HUALME ROCIO (1)_1.jpg (sin brackets)
# Copiado: LEIVA QUIÑEMIL FERNANDA  (1).jpg (con brackets)
# Copiado: LEIVA QUIÑEMIL FERNANDA  (1)_1.jpg (con brackets)
# Copiado: LILLO GARRIDO ISIDORA  (1).jpg (sin brackets)
# Copiado: LILLO GARRIDO ISIDORA  (1)_1.jpg (sin brackets)
# Copiado: LILLO RIFFO BENJAMIN (2).jpg (sin brackets)
# Copiado: LINCOLAF CAYUMAN CAMILA 19-01-08 (2).jpg (con brackets)
# Copiado: LLANO AGUILERA LILIAN 16-12-09 (1).jpg (con brackets)
# Copiado: LLANOS VASQUEZ VITTORIO.jpg (sin brackets)
# Copiado: LLANOS VASQUEZ ZINNEDYNE.jpg (con brackets)
# Copiado: LLANQUINAO ROMERO FERNANDA 08-05-07 (1).jpg (sin brackets)
# Copiado: LLAUPE LLONCON TAMARA 2.jpg (sin brackets)
# Copiado: LOCARE TRANAMIL CARLOS.jpg (con brackets)
# Copiado: LOPEZ BURGOS LAURA 22-06-09 (1).jpg (sin brackets)
# Copiado: LOYOLA OLIVARES YESENIA  (2).jpg (con brackets)
# Copiado: LOYOLA OLIVARES YESENIA  (2)_1.jpg (con brackets)
# Copiado: LUNA TORRES ANGEL 21-05-08 (1).jpg (sin brackets)
# Copiado: MACAYA MUÑOZ IGNACIO.jpg (con brackets)
# Copiado: MALDONADO FLORES AMANDA (2).jpg (sin brackets)
# Copiado: MALDONADO HENRIQUEZ PIA.jpg (con brackets)
# Copiado: MALIQUEO HUARACAN DIEGO_2.jpg (con brackets)
# Copiado: MALIQUEO HUARACAN JOSE  (1).jpg (sin brackets)
# Copiado: MALIQUEO HUARACAN JOSE  (1)_1.jpg (sin brackets)
# Copiado: MALIQUEO HUARACAN JOSE.jpg (sin brackets)
# Copiado: MALIQUEO HUARCAN JOSE  (2).jpg (sin brackets)
# Copiado: MALIQUEO VERGARA MARTINA  (1).jpg (sin brackets)
# Copiado: MANDUJANO MORAN RAFAELA.jpg (sin brackets)
# Copiado: MANDUJANO MORAN RAFAELA_1.jpg (sin brackets)
# Copiado: MANDUJANO MORAN RAFAELA_2.jpg (sin brackets)
# Copiado: MANDUJANO MORAN_R_20160706_82591744_1.jpg (sin brackets)
# Copiado: MANQUEO PINCHULAF NAYARET_1.jpg (sin brackets)
# Copiado: MANQUI CONTRERAS BENJAMIN (1).jpg (sin brackets)
# Copiado: MANSILLA BARRIGA FLORENCIA (2).jpg (sin brackets)
# Copiado: MANSILLA BARRIGA FLORENCIA.jpg (con brackets)
# Copiado: MARDONES MOLINA CAMILA.jpg (con brackets)
# Copiado: MARIHUAN CATRILAF ANTONELLA.jpg (sin brackets)
# Copiado: MARIN COÑA SUSAN.jpg (con brackets)
# Copiado: MARIN COÑA SUSAN_3.jpg (con brackets)
# Copiado: MARTINEZ ARAVENA TRINIDAD.jpg (sin brackets)
# Copiado: MARTINEZ CARDENAS VALENTINA (2).jpg (sin brackets)
# Copiado: MARTINEZ MORENO ALONSO  (2).jpg (sin brackets)
# Copiado: MARTINEZ MUÑOZ GUSTAVO  (1).jpg (sin brackets)
# Copiado: MARTINEZ ORTEGA MARIA  (1).jpg (con brackets)
# Copiado: MARTINEZ ORTEGA MARIA  (1)_1.jpg (con brackets)
# Copiado: MARTINEZ ORTEGA MARIA.jpg (con brackets)
# Copiado: MARTINEZ ORTEGA MARIA_1.jpg (con brackets)
# Copiado: MARTINEZ ORTEGA MARIA_2.jpg (con brackets)
# Copiado: MARTINEZ TIZNADO MARIA PAZ  (2).jpg (sin brackets)
# Copiado: MATAMALA HERRERA 10-06-06.jpg (con brackets)
# Copiado: MAYORGA SAAVEDRA ALEXIS  15-12-2006 (2).jpg (con brackets)
# Copiado: MAYORGA SAAVEDRA ALEXIS  15-12-2006 (4).jpg (con brackets)
# Copiado: MEDINA SANDOVAL ALONSO (2).jpg (sin brackets)
# Copiado: MEDINA SANDOVAL ALONSO.jpg (sin brackets)
# Copiado: MELLA MENDEZ JUAN.jpg (con brackets)
# Copiado: MELLADO KUNZ AGUSTIN 30-09-04.jpg (con brackets)
# Copiado: MENDOZA QUIROZ ALAN.jpg (con brackets)
# Copiado: MENDOZA QUIROZ ALAN_1.jpg (sin brackets)
# Copiado: MEZA GARCIA AMALIA 18-07-13 (2).jpg (sin brackets)
# Copiado: MEZA GARCIA AMALIA.jpg (sin brackets)
# Copiado: MEZA GARCIA AMALIA_1.jpg (sin brackets)
# Copiado: MEZA GARCIA AMALIA_2.jpg (sin brackets)
# Copiado: MEZA GARCIA AMALIA_3.jpg (sin brackets)
# Copiado: MILLACOY MELIÑIR MATIAS  (1).jpg (sin brackets)
# Copiado: MILLAÑANCO LEFIPAN AYELEN  (2).jpg (sin brackets)
# Copiado: MILLAÑANCO LEFIPAN AYELEN  (2)_1.jpg (sin brackets)
# Copiado: MILLAÑANCO LEFIPAN AYELEN.jpg (sin brackets)
# Copiado: MOLINA BIZAMA MICHELLE_1.jpg (con brackets)
# Copiado: MOLINA BIZAMA MICHELLE_2.jpg (con brackets)
# Copiado: MOLINA RAIN ANTONIA 01-02-06 (2).jpg (con brackets)
# Copiado: MOLINA RIVAS SABASTIAN.jpg (con brackets)
# Copiado: MOLINA RIVAS SABASTIAN_1.jpg (con brackets)
# Copiado: MOLINA RIVAS SEBASTIAN.jpg (sin brackets)
# Copiado: MOLINA RIVAS SEBASTIAN_1.jpg (con brackets)
# Copiado: MOLINA RIVAS SEBASTIAN_2.jpg (sin brackets)
# Copiado: MONSALVE ACUÑA SANDOR.jpg (sin brackets)
# Copiado: MONSALVE BARRIENTOS YARIXSA.jpg (con brackets)
# Copiado: MONTECINOS PAINENAO ROCIO  (2).jpg (sin brackets)
# Copiado: MONTECINOS PAINENAO ROCIO  (2)_1.jpg (sin brackets)
# Copiado: MONTENEGRO BARRIENTOS GASPAR  (2).jpg (sin brackets)
# Copiado: MONTENEGRO BARRIENTOS GASPAR  (2)_1.jpg (sin brackets)
# Copiado: MORA CONTRERAS MATILDA.jpg (sin brackets)
# Copiado: MORA CONTRERAS MATILDA_1.jpg (con brackets)
# Copiado: MORA CONTRERAS MATILDA_2.jpg (con brackets)
# Copiado: MORA VERGARA GERMAN (3).jpg (sin brackets)
# Copiado: MORA VERGARA GERMAN.jpg (sin brackets)
# Copiado: MORA VERGARA GERMAN_1.jpg (sin brackets)
# Copiado: MORALES CID ALEJANDRO (2).jpg (con brackets)
# Copiado: MORALES QUEPUCURA JULIETA (2).jpg (con brackets)
# Copiado: MORALES RIOSECO MARTIN P.jpg (con brackets)
# Copiado: MORALES RIOSECO MARTIN.jpg (con brackets)
# Copiado: MORALES VERGARA CONSTANZA.jpg (con brackets)
# Copiado: MORALES VERGARA CONSTANZA_1.jpg (con brackets)
# Copiado: MULLER FONSECA FRANCESCA (2).jpg (con brackets)
# Copiado: MUÑOZ DIAZ VICTORIA .jpg (sin brackets)
# Copiado: MUÑOZ DIAZ VICTORIA _1.jpg (sin brackets)
# Copiado: MUÑOZ GUTIERREZ CESAR.jpg (con brackets)
# Copiado: MUÑOZ MADRID ISIDORA.jpg (sin brackets)
# Copiado: MUÑOZ MADRID ISIDORA_1.jpg (sin brackets)
# Copiado: MUÑOZ MOLINA TATIANA 12-05-05.jpg (con brackets)
# Copiado: MUÑOZ POBLETE DANTE  (2).jpg (sin brackets)
# Copiado: MUÑOZ TORRES BAIRON  (2).jpg (sin brackets)
# Copiado: MUÑOZ TORRES BAIRON  (2)_1.jpg (sin brackets)
# Copiado: NAHUEL GUERRERO CATALINA 28-05-11 (1).jpg (sin brackets)
# Copiado: NAHUEL MARIVIL ARELY  (1).jpg (sin brackets)
# Copiado: NAHUEL MARIVIL ARELY  (1)_1.jpg (sin brackets)
# Copiado: NAHUEL MARIVIL ARELY  (1)_2.jpg (sin brackets)
# Copiado: NAIN MELIN KATTY  (2).jpg (con brackets)
# Copiado: NAVARRETE NECULÑIR MATIAS 10-09-07.jpg (sin brackets)
# Copiado: NECULAN HUAIQUILAF GENESIS (1).jpg (sin brackets)
# Copiado: NOVOA ARRIAGADA ANTONIA.jpg (sin brackets)
# Copiado: NOVOA ARRIAGADA ANTONIA_1.jpg (sin brackets)
# Copiado: NOVOA GONZALEZ GASPAR 14-12-08 (2).jpg (sin brackets)
# Copiado: NUÑEZ CASTILLO MARTIN  (1).jpg (con brackets)
# Copiado: NUÑEZ CASTILLO MARTIN  (1)_1.jpg (con brackets)
# Copiado: NUÑEZ CASTILLO MARTIN (2).jpg (sin brackets)
# Copiado: NUÑEZ CASTILLO MARTIN.jpg (con brackets)
# Copiado: OLIVARES HERNANDEZ CRISTELL (2).jpg (sin brackets)
# Copiado: OLIVERA SANDOVAL MILLARAY  (2).jpg (sin brackets)
# Copiado: OMANZOR FERNANDEZ ANTONELLA.jpg (con brackets)
# Copiado: ORTEGA GALLEGOS MIKAL_1.jpg (con brackets)
# Copiado: ORTEGA GALLEGOS MIKAL_2.jpg (con brackets)
# Copiado: ORTIZ DUATH MAXIMILIANO (2).jpg (sin brackets)
# Copiado: ORTIZ DUATH MAXIMILIANO.jpg (sin brackets)
# Copiado: ORTIZ DUATH MAXIMILIANO_1.jpg (sin brackets)
# Copiado: ORTIZ DUATH MAXIMILIANO_2.jpg (sin brackets)
# Copiado: OSORIO CONTRERAS MARTIN (2).jpg (con brackets)
# Copiado: OSORIO CONTRERAS MARTIN P.jpg (sin brackets)
# Copiado: PACHECO CONTRERAS  BARBARA 18-04-11 (2).jpg (sin brackets)
# Copiado: PACHECO CONTRERAS  BARBARA.jpg (con brackets)
# Copiado: PACHECO ESTRADA CONSUELO 22-03-03.jpg (con brackets)
# Copiado: PACHECO MORALES ROMINA 26-08-03.jpg (con brackets)
# Copiado: PADILLA BRAVO DOMINIQUE.jpg (sin brackets)
# Copiado: PAILLAL CHEHUAN ALEN 12-09-11 (2).jpg (sin brackets)
# Copiado: PAILLAL CHEHUAN ALEN.jpg (sin brackets)
# Copiado: PAILLAL CHEHUAN ALEN_1.jpg (sin brackets)
# Copiado: PAILLAL CHEHUAN ILWEN  (2).jpg (con brackets)
# Copiado: PAILLALEO TEJO SOFIA (1).jpg (sin brackets)
# Copiado: PAINE CONCHA MARTHYNA 05-07-09 (2).jpg (con brackets)
# Copiado: PAINEN HUENTEN ZASHA  (1).jpg (sin brackets)
# Copiado: PALAVECINO MARDONES JOAQUIN 28-03-05 (1).jpg (sin brackets)
# Copiado: PARRA GARCIA VIOLETA.jpg (sin brackets)
# Copiado: PARRA LAGOS PIA.jpg (sin brackets)
# Copiado: PEÑA MOYANO MAGDALENA 07-04-10 (2).jpg (sin brackets)
# Copiado: PEÑA SAGREDO MARTINA.jpg (con brackets)
# Copiado: PEÑA SAGREDO MARTINA_1.jpg (con brackets)
# Copiado: PEÑA SAGREDO MATIAS  (1).jpg (con brackets)
# Copiado: PEÑA SAGREDO MATIAS  (1)_1.jpg (con brackets)
# Copiado: PEÑAILILLO CAÑETE DAMIAN.jpg (sin brackets)
# Copiado: PICARTE CANTERO ANTONIO 06-07-07.jpg (con brackets)
# Copiado: PINO MARDONES EMILIA 19-05-10.jpg (con brackets)
# Copiado: PIZARRO LAGOS YAJAIRA.jpg (con brackets)
# Copiado: PLAZA TORRES FLORENCIA.jpg (con brackets)
# Copiado: POBLETE RIFFO FRANCO (2).jpg (sin brackets)
# Copiado: POZA MELLA CONSTANZA 11-02-12.jpg (sin brackets)
# Copiado: QUEUPUMIL HUENTECURA LAURA  (1).jpg (sin brackets)
# Copiado: QUEUPUMIL HUENTECURA LAURA  (1)_1.jpg (sin brackets)
# Copiado: QUEVEDO RIVERA MILEY (2).jpg (con brackets)
# Copiado: QUIDEL CAMPOS ISABELLA  (1).jpg (sin brackets)
# Copiado: QUIJADA OSSANDON MARIO (1).jpg (sin brackets)
# Copiado: QUILIMPAN SEGUEL MILLARAY 13-08-01.jpg (con brackets)
# Copiado: QUILODRAN BARRA JAVIERA.jpg (con brackets)
# Copiado: QUILONDRAN ROA LEANDRO  (2).jpg (sin brackets)
# Copiado: QUINTRIQUEO MUÑOZ RODRIGO13-04-08 (2).jpg (sin brackets)
# Copiado: RAMOS BASTIAS MACARENA 26-04-03.jpg (con brackets)
# Copiado: RAMOS BASTIAS MACARENA_1.jpg (con brackets)
# Copiado: RAMOS HOFFMAN JULIETA.jpg (sin brackets)
# Copiado: RAMOS HOFFMAN JULIETA_1.jpg (sin brackets)
# Copiado: RAMOS HOFFMANN JULIETA.jpg (sin brackets)
# Copiado: RAMOS REDEL BASTIAN (2).jpg (sin brackets)
# Copiado: RAÑILEO PEREZ FLORENCIA  (2).jpg (sin brackets)
# Copiado: REUMAY ÑANCO GABRIEL_3.jpg (con brackets)
# Copiado: REYES ASTETE INGRID.jpg (con brackets)
# Copiado: REYES BUSTOA PASCALE.jpg (sin brackets)
# Copiado: REYES BUSTOS PASCALE_1.jpg (sin brackets)
# Copiado: REYES GARCES MARTINA (2).jpg (sin brackets)
# Copiado: REYES ULLOA CONSTANZA.jpg (con brackets)
# Copiado: RIFFO GODOY JAVIERA 21-05-11.jpg (con brackets)
# Copiado: RIOS MARQUEZ MATEO.jpg (con brackets)
# Copiado: RIOS MARQUEZ MATEO_1.jpg (con brackets)
# Copiado: RIQUELME LAGOS MIGUEL.jpg (sin brackets)
# Copiado: RISCO PRADO CARLOS.jpg (sin brackets)
# Copiado: RISCO PRADO CARLOS_1.jpg (sin brackets)
# Copiado: RISCO PRADO CARLOS_2.jpg (sin brackets)
# Copiado: RISCO PRADO CARLOS_3.jpg (sin brackets)
# Copiado: RISCO PRADO CARLOS_4.jpg (sin brackets)
# Copiado: RIVAS ABARZUA FERNANDA  (2).jpg (sin brackets)
# Copiado: RIVAS ABARZUA FERNANDA  (2)_1.jpg (sin brackets)
# Copiado: RIVAS ABARZUA FERNANDA 3  (2).jpg (sin brackets)
# Copiado: RIVAS ABARZUA FERNANDA 3  (2)_1.jpg (sin brackets)
# Copiado: RIVERA FRIDERICKSEN MAXIMILIANO  (1).jpg (sin brackets)
# Copiado: RIVERA FRIDERICKSEN MAXIMILIANO  (1)_1.jpg (sin brackets)
# Copiado: RIVERA NAVARRO MAURICIO 22542471-3 (2).jpg (sin brackets)
# Copiado: ROA SUAZO DAMARIS.jpg (con brackets)
# Copiado: ROA SUAZO DAMARIS_2.jpg (con brackets)
# Copiado: ROA SUAZO DAMARIS_3.jpg (con brackets)
# Copiado: ROCHA CHAVEZ JULIETA  (2).jpg (sin brackets)
# Copiado: RODRIGUEZ AGUILERA PIA.jpg (con brackets)
# Copiado: RODRIGUEZ AGUILERA PIA_1.jpg (con brackets)
# Copiado: ROJAS ACUÑA KATHERINE 26-04-1999.jpg (con brackets)
# Copiado: ROMERO IBAÑEZ JOSEFA  (1).jpg (sin brackets)
# Copiado: ROMERO IBAÑEZ JOSEFA.jpg (sin brackets)
# Copiado: ROMERO IBAÑEZ JOSEFA_1.jpg (sin brackets)
# Copiado: SAAVEDRA ZARZAR GABRIELA.jpg (sin brackets)
# Copiado: SAAVEDRA ZARZAR GABRIELA_1.jpg (sin brackets)
# Copiado: SAAVEDRA ZARZAR GABRIELA_2.jpg (sin brackets)
# Copiado: SALAZAR CANIULEF PATRICIA 21-01-03_1.jpg (con brackets)
# Copiado: SALAZAR GATICA FRANCISCA.jpg (sin brackets)
# Copiado: SALAZAR GATICA FRANCISCA_1.jpg (sin brackets)
# Copiado: SALINAS CANCINO CRYSTAL 12-11-02.jpg (con brackets)
# Copiado: SALINAS TRONCOSO VANESA P.jpg (sin brackets)
# Copiado: SALINAS TRONCOSO VANESA.jpg (con brackets)
# Copiado: SAN JUAN CISTERNA EMILIA (2).jpg (sin brackets)
# Copiado: SANCHEZ MONASTERIO FELIPE.jpg (con brackets)
# Copiado: SANCHEZ OPASO AGUSTINA.jpg (con brackets)
# Copiado: SANCHEZ OPASO AGUSTINA_1.jpg (con brackets)
# Copiado: SANCHEZ OPASO ANTONELLA (2).jpg (sin brackets)
# Copiado: SANCHEZ OPAZO AGUSTINA 2.jpg (con brackets)
# Copiado: SANCHEZ OPAZO AGUSTINA.jpg (sin brackets)
# Copiado: SANCHEZ OPAZO AGUSTINA_1.jpg (con brackets)
# Copiado: SANCHEZ OPAZO AGUSTINA_2.jpg (con brackets)
# Copiado: SANCHEZ OPAZO AGUSTINA_3.jpg (con brackets)
# Copiado: SANCHEZ OPAZO AGUSTINA_4.jpg (con brackets)
# Copiado: SANDOVAL BUSTOS SOFIA  (1).jpg (sin brackets)
# Copiado: SANDOVAL BUSTOS SOFIA  (1)_1.jpg (sin brackets)
# Copiado: SANDOVAL DIEGO LEANDRO  (2).jpg (con brackets)
# Copiado: SANDOVAL DIEGO LEANDRO  (2)_1.jpg (con brackets)
# Copiado: SANDOVAL FLORES CATALINA.jpg (con brackets)
# Copiado: SANDOVAL MANQUEL MARIA  (1).jpg (con brackets)
# Copiado: SANDOVAL MANQUEL MARIA  (1)_1.jpg (con brackets)
# Copiado: SANDOVAL MELLA ALEJANDRO.jpg (con brackets)
# Copiado: SANDOVAL MELLA ALEJANDRO_2.jpg (sin brackets)
# Copiado: SANDOVAL PARADA EMA.jpg (sin brackets)
# Copiado: SANDOVAL PARADA EMA_1.jpg (sin brackets)
# Copiado: SANDOVAL PARADA EMMA (3).jpg (sin brackets)
# Copiado: SANDOVAL RAIN AYLIN 06-05-11.jpg (con brackets)
# Copiado: SANDOVAL RAIN PAULINA.jpg (con brackets)
# Copiado: SANDOVAL RAIN PAULINA_2.jpg (con brackets)
# Copiado: SANDOVAL RAIN PAULINA_3.jpg (con brackets)
# Copiado: SANDOVAL SANDOVAL CAROLINA  (2).jpg (con brackets)
# Copiado: SANDOVAL SANDOVAL CAROLINA  (2)_1.jpg (con brackets)
# Copiado: SANDOVAL SANDOVAL CAROLINA  (2)_2.jpg (con brackets)
# Copiado: SANDOVAL SANDOVAL CAROLINA.jpg (sin brackets)
# Copiado: SANDOVAL SANDOVAL CAROLINA_1.jpg (con brackets)
# Copiado: SANHEZA VASQUIEZ GASPAR  (1).jpg (con brackets)
# Copiado: SANHEZA VASQUIEZ GASPAR  (1)_1.jpg (con brackets)
# Copiado: SANHEZA VASQUIEZ GASPAR  (1)_2.jpg (con brackets)
# Copiado: SANHUEZA INOSTROZA ELIZABETH (2).jpg (sin brackets)
# Copiado: SANTANDER PERALTA JAVIERA (1).jpg (sin brackets)
# Copiado: SCHULZ JIMENEZ SONIA.jpg (con brackets)
# Copiado: SCHULZ JIMENEZ SONIA_1.jpg (con brackets)
# Copiado: SEPULVEDA CORONADO MARIA JOSE 03-09-08 (1).jpg (con brackets)
# Copiado: SEPULVEDA CRUZ ANGELA.jpg (con brackets)
# Copiado: SEPULVEDA ESPINOZA JOAQUIN 23-10-05 (2).jpg (con brackets)
# Copiado: SEPULVEDA ESPINOZA JOAQUIN.jpg (con brackets)
# Copiado: SEPULVEDA ESPINOZA JOAQUIN_1.jpg (con brackets)
# Copiado: SEPULVEDA HORN ALISON.jpg (con brackets)
# Copiado: SEPULVEDA SEPULVEDA SOFIA  12-06-09 (2).jpg (con brackets)
# Copiado: SEPULVEDA SEPULVEDA SOFIA.jpg (con brackets)
# Copiado: SEVILLA HERRERA ANTONELLA  (2).jpg (con brackets)
# Copiado: SEVILLA HERRERA ANTONELLA  (2)_1.jpg (con brackets)
# Copiado: SEVILLA HERRERA ANTONELLA  (2)_2.jpg (con brackets)
# Copiado: SEVILLA HERRERA ANTONELLA  (2)_3.jpg (con brackets)
# Copiado: SIERRA VIDAL FERNANDA_3.jpg (con brackets)
# Copiado: SILVA MELLA TOMAS  (1).jpg (sin brackets)
# Copiado: SILVA MELLA TOMAS  (1)_1.jpg (sin brackets)
# Copiado: SILVA SOLIS AGUSTIN  (2).jpg (con brackets)
# Copiado: SILVA SOLIS AGUSTIN  (2)_1.jpg (con brackets)
# Copiado: SILVA VASQUEZ STEFANIA.jpg (con brackets)
# Copiado: SOTO HENRIQUEZ AGUSTIN  (1).jpg (sin brackets)
# Copiado: SOTO HENRIQUEZ AGUSTIN  (1)_1.jpg (sin brackets)
# Copiado: SOTO MOLINA JUAN LUIS 226-09-01 (2).jpg (con brackets)
# Copiado: SOTO PEREZ FLORENCIA  (2).jpg (sin brackets)
# Copiado: SOTO PEREZ FLORENCIA  (2)_1.jpg (sin brackets)
# Copiado: SOTO PEREZ FLORENCIA  (2)_2.jpg (sin brackets)
# Copiado: SOTO ROMERO SOFIA.jpg (sin brackets)
# Copiado: SOTO ROMERO SOFIA_1.jpg (sin brackets)
# Copiado: SOTO TOLEDO DUBAN.jpg (sin brackets)
# Copiado: SUBIABRE ARELLANO LISSETTE 20-12-09.jpg (con brackets)
# Copiado: TAPIA PEREZ SOFIA  (1).jpg (con brackets)
# Copiado: TAPIA PEREZ SOFIA  (1)_1.jpg (con brackets)
# Copiado: TASSISTRO SANCHEZ ANTONELLA 13-08-04.jpg (con brackets)
# Copiado: TERAN TORO CINTHIA.jpg (sin brackets)
# Copiado: TERAN TORO CYNTHIA.jpg (con brackets)
# Copiado: TILLERIA SEPULVEDA JAVIERA  (2).jpg (sin brackets)
# Copiado: TILLERIA SEPULVEDA JAVIERA (2).jpg (con brackets)
# Copiado: TILLERIA SEPULVEDA JAVIERA (2)_1.jpg (con brackets)
# Copiado: TORRES ARANCIBIA AGUSTIN  (1).jpg (sin brackets)
# Copiado: TORRES ARANCIBIA AGUSTIN  (1)_1.jpg (sin brackets)
# Copiado: TORRES BARRIGA LYSSETE.jpg (con brackets)
# Copiado: TORRES CALAPAY NEZARET 01-09-07 (1).jpg (sin brackets)
# Copiado: TORRES PONCE SOFIA  (2).jpg (con brackets)
# Copiado: TORRES PONCE SOFIA  (2)_1.jpg (con brackets)
# Copiado: TORRES PONCE SOFIA  (2)_2.jpg (con brackets)
# Copiado: TRECANAO ESCOBEDO SARA 10-05-2011 (1).jpg (sin brackets)
# Copiado: TRIPAÑAN SAN MARTIN SABINA  (2).jpg (sin brackets)
# Copiado: TRIPAÑAN SAN MARTIN SABINA  (2)_1.jpg (sin brackets)
# Copiado: TRONCOSO CAMPOS ANAIS 27-07-04.jpg (con brackets)
# Copiado: TURRA COÑA SOFIA.jpg (sin brackets)
# Copiado: TURRA COÑA SOFIA_1.jpg (sin brackets)
# Copiado: TURRA COÑA SOFIA_2.jpg (sin brackets)
# Copiado: UMANZOR FERNANDEZ ANTONELLA.jpg (sin brackets)
# Copiado: UMANZOR FERNANDEZ_ ANTONELLA (1).jpg (sin brackets)
# Copiado: URRA MELINAO FELIPE  (2).jpg (sin brackets)
# Copiado: VALDES HUENUMAN IGNACIA.jpg (con brackets)
# Copiado: VALENZUELA HERNANDEZ ARACELLY.jpg (con brackets)
# Copiado: VARAS VALDEBENITO EZEQUIEL.jpg (sin brackets)
# Copiado: VARAS VALDEBENITO EZEQUIEL_1.jpg (sin brackets)
# Copiado: VARAS VALDEBENITO EZEQUIEL_2.jpg (sin brackets)
# Copiado: VARGAS LABRAÑA AMANDA.jpg (sin brackets)
# Copiado: VARGAS LABRAÑA AMANDA_1.jpg (sin brackets)
# Copiado: VASQUEZ BASTIAS DANIEL  (1).jpg (con brackets)
# Copiado: VASQUEZ BASTIAS DANIEL  (1)_1.jpg (con brackets)
# Copiado: VASQUEZ LILLO NICOLÁS 15-09-02.jpg (con brackets)
# Copiado: VASQUEZ MANRIQUEZ MAXIMILIANO  (2).jpg (con brackets)
# Copiado: VASQUEZ MANRIQUEZ MAXIMILIANO.jpg (sin brackets)
# Copiado: VASQUEZ MANRIQUEZ MAXIMILIANO_1.jpg (sin brackets)
# Copiado: VASQUEZ ZABATEL PABLO.jpg (con brackets)
# Copiado: VEGA PAREDES CATALINA 16-10-03 (1).jpg (sin brackets)
# Copiado: VEJAR CID VICTOR.jpg (sin brackets)
# Copiado: VELASQUEZ CASTRO MARTINA.jpg (sin brackets)
# Copiado: VELASQUEZ CASTRO MARTINA_1.jpg (sin brackets)
# Copiado: VELASQUEZ MORALES ANTONIO (2).jpg (sin brackets)
# Copiado: VELASQUEZ MORALES ANTONIO (2)_1.jpg (sin brackets)
# Copiado: VELIZ MARDONES KATHERINE (2).jpg (sin brackets)
# Copiado: VELIZ MARDONES KATHERINE (2)_1.jpg (sin brackets)
# Copiado: VENEGA LUENGO ISIDORA.jpg (con brackets)
# Copiado: VENEGA LUENGO ISIDORA_1.jpg (con brackets)
# Copiado: VENEGAS ARIAS JAVIERA  (1).jpg (con brackets)
# Copiado: VENEGAS ARIAS JAVIERA  (1)_1.jpg (con brackets)
# Copiado: VENEGAS LUENGO ISIDORA.jpg (sin brackets)
# Copiado: VERA CEBALLOS JAVIERA  (2).jpg (sin brackets)
# Copiado: VERA CEBALLOS JAVIERA  (2)_1.jpg (sin brackets)
# Copiado: VERA VIVANCO SOFIA.jpg (sin brackets)
# Copiado: VILLENAS LEAL AKILES.jpg (con brackets)
# Copiado: WIEDERHOLD DEUMACAN MAXIMILIANO.jpg (con brackets)
# Copiado: WIEDERHOLD DEUMACAN MAXIMILIANO_1.jpg (sin brackets)
# Copiado: YAGODE CASTRO ALEJANDRO.jpg (sin brackets)
# Copiado: ZAPATA PAIVE IAN (2).jpg (sin brackets)
# Copiado: ZAPATA PAIVE IAN.jpg (sin brackets)
# Copiado: ZAPATA ULLOA PAULO 27-08-04.jpg (con brackets)
# Copiado: ZUÑIGA FONSECA LUCIANO (3).jpg (con brackets)
# Procesamiento completado. 386/715 imágenes sin brackets.
